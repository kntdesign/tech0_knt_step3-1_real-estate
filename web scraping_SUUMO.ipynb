# %%
pip install tenacity
# Out:
# Collecting tenacity
#   Obtaining dependency information for tenacity from https://files.pythonhosted.org/packages/f4/f1/990741d5bb2487d529d20a433210ffa136a367751e454214013b441c4575/tenacity-8.2.3-py3-none-any.whl.metadata
#   Downloading tenacity-8.2.3-py3-none-any.whl.metadata (1.0 kB)
# Downloading tenacity-8.2.3-py3-none-any.whl (24 kB)
# Installing collected packages: tenacity
# Successfully installed tenacity-8.2.3
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup
from tenacity import retry, stop_after_attempt,wait_exponential
import urllib
import time
import numpy as np
import pandas as pd

#tenacityのライブラリに関する記事は下記
#https://zenn.dev/taroman_zenn/articles/dd0b33a3a37d1e

# %%
#Step1必要な情報を取得する

#SUUMO上で必要な情報を検索する
#今回はペルソナに合致した下記の条件を設定｜ペルソナ：https://www.dropbox.com/scl/fi/pdo0x2sm6es6n76sek2i7/Tech0_STEP3-1_-_v1.0.pdf?rlkey=2attz3z14yyoanwm53spxk6t1&dl=0
#検索条件：東京都内、20万円以下（管理費・共益費込み）、2K以上の間取り、駅徒歩10分以内、バストイレ別、室内洗濯機置場、
#取得したURL：https://suumo.jp/jj/chintai/ichiran/FR301FC001/?ar=030&bs=040&pc=50&smk=&po1=25&po2=99&shkr1=03&shkr2=03&shkr3=03&shkr4=03&sc=13101&sc=13102&sc=13103&sc=13104&sc=13105&sc=13113&sc=13106&sc=13107&sc=13108&sc=13118&sc=13121&sc=13122&sc=13123&sc=13109&sc=13110&sc=13111&sc=13112&sc=13114&sc=13115&sc=13120&sc=13116&sc=13117&sc=13119&ta=13&cb=0.0&ct=20.0&co=1&md=05&md=06&md=07&md=08&md=09&md=10&md=11&md=12&md=13&md=14&et=10&mb=0&mt=9999999&cn=9999999&tc=0400301&tc=0400501&fw2=

#複数ページの情報をまとめて取得するリストを作成
data_samples = []

#スクレイピングするページ数を指定
#1ページの表示件数を最大の50件に設定した上で、出力されたページ数237を上回るように設定する
max_page = 240

#SUUMOで自分が調べたい地域を指定して検索し、出力したページのURL
URL = 'https://suumo.jp/jj/chintai/ichiran/FR301FC001/?ar=030&bs=040&pc=50&smk=&po1=25&po2=99&shkr1=03&shkr2=03&shkr3=03&shkr4=03&sc=13101&sc=13102&sc=13103&sc=13104&sc=13105&sc=13113&sc=13106&sc=13107&sc=13108&sc=13118&sc=13121&sc=13122&sc=13123&sc=13109&sc=13110&sc=13111&sc=13112&sc=13114&sc=13115&sc=13120&sc=13116&sc=13117&sc=13119&ta=13&cb=0.0&ct=20.0&co=1&md=05&md=06&md=07&md=08&md=09&md=10&md=11&md=12&md=13&md=14&et=10&mb=0&mt=9999999&cn=9999999&tc=0400301&tc=0400501&fw2='
suumo_URL ='https://suumo.jp/'

#試行回数3回、リトライ間の初期待機時間10秒、連続するリトライの時間を100秒にする（指数関数的に増やすが、100秒までで制限する）
#Pythonでは、デコレータの引数を|で結合することはできないため、,で指定すること
@retry(stop=stop_after_attempt(3),wait=wait_exponential(multiplier=10, min=10, max=100))
def load_page(URL):
    html = requests.get(URL)
    soup = BeautifulSoup(html.content, 'html.parser')
    return soup

# %%
# 処理時間を測りたい
start = time.time()
times = []

#関数については下記を参考にすること
#enumerate()関数 https://note.nkmk.me/python-enumerate-start/
#strip()関数 https://note.nkmk.me/python-str-remove-strip/#strip

for page in range(1,max_page+1):
    before = time.time()
    #ページ情報
    soup = load_page(URL.format(page))
    #物件リストを指定
    mother = soup.find_all(class_='cassetteitem')
    
    #物件ごとの処理
    for child in mother:
        
        #建物情報
        data_home = []
        #カテゴリ
        data_home.append(child.find(class_='ui-pct ui-pct--util1').text)
        #建物名
        data_home.append(child.find(class_='cassetteitem_content-title').text)
        #住所
        data_home.append(child.find(class_='cassetteitem_detail-col1').text)
        #最寄駅のアクセス
        children = child.find(class_='cassetteitem_detail-col2')
        for id, grandchild in enumerate(children.find_all(class_='cassetteitem_detail-text')):
            data_home.append(grandchild.text)
        #築年数と階数
        children = child.find(class_='cassetteitem_detail-col3')
        for grandchild in children.find_all('div'):
            data_home.append(grandchild.text)
        
        #部屋情報
        rooms = child.find(class_='cassetteitem_other')
        for room in rooms.find_all(class_='js-cassette_link'):
            data_room = []
            
            #部屋情報が入っている表を探索
            for id_, grandchild in enumerate(room.find_all('td')):
                #階
                if id_ == 2:
                    data_room.append(grandchild.text.strip())
                #家賃と管理費
                elif id_ == 3:
                    data_room.append(grandchild.find(class_='cassetteitem_other-emphasis ui-text--bold').text)
                    data_room.append(grandchild.find(class_='cassetteitem_price cassetteitem_price--administration').text)
                #敷金と礼金
                elif id_ == 4:
                    data_room.append(grandchild.find(class_='cassetteitem_price cassetteitem_price--deposit').text)
                    data_room.append(grandchild.find(class_='cassetteitem_price cassetteitem_price--gratuity').text)
                #間取りと面積
                elif id_ == 5:
                    data_room.append(grandchild.find(class_='cassetteitem_madori').text)
                    data_room.append(grandchild.find(class_='cassetteitem_menseki').text)
                #url
                elif id_ == 8:
                    get_url = grandchild.find(class_='js-cassette_link_href cassetteitem_other-linktext').get('href')
                    abs_url = urllib.parse.urljoin(suumo_URL, get_url)
                    data_room.append(abs_url)
            #物件情報と部屋情報を結合する
            data_sample = data_home + data_room,
            data_samples.append(data_sample)

    #1アクセスごとに1秒休む
    time.sleep(1)
    
    #進捗確認
    #このページの作業時間を表示
    after = time.time()
    running_time = after - before
    times.append(running_time)
    print(f'総取得件数:{len(data_samples)}')
    #作業進捗
    complete_ratio = round(page/max_page*100,3)
    print(f'完了:{complete_ratio}%')
    #作業の残り時間目安を表示
    running_mean = np.mean(times)
    running_required_time = running_mean * (max_page - page)
    hour = int(running_required_time/3600)
    minute = int((running_required_time%3600)/60)
    second = int(running_required_time%60)
    print(f'残り時間:{hour}時間{minute}分{second}秒\n')

    
# 処理時間を測りたい
finish = time.time()
running_all = finish - start
print('総経過時間：',running_all)
sound()
# Out:
# 総取得件数:178
# 完了:10.0%
# 残り時間:0時間0分58秒
#
# 総取得件数:356
# 完了:20.0%
# 残り時間:0時間0分41秒
#
# 総取得件数:534
# 完了:30.0%
# 残り時間:0時間0分37秒
#
# 総取得件数:712
# 完了:40.0%
# 残り時間:0時間0分30秒
#
# 総取得件数:890
# 完了:50.0%
# 残り時間:0時間0分24秒
#
# 総取得件数:1068
# 完了:60.0%
# 残り時間:0時間0分18秒
#
# 総取得件数:1246
# 完了:70.0%
# 残り時間:0時間0分13秒
#
# 総取得件数:1424
# 完了:80.0%
# 残り時間:0時間0分8秒
#
# 総取得件数:1602
# 完了:90.0%
# 残り時間:0時間0分4秒
#
# 総取得件数:1780
# 完了:100.0%
# 残り時間:0時間0分0秒
#
# 総経過時間： 43.56750202178955
# /bin/bash: rundll32: command not found

# %%
data_samples
# Out:
# [(['賃貸一戸建て',
#    '奥山方',
#    '東京都荒川区西日暮里２',
#    'ＪＲ山手線/日暮里駅 歩5分',
#    'ＪＲ山手線/西日暮里駅 歩10分',
#    'ＪＲ常磐線/三河島駅 歩9分',
#    '築41年',
#    '2階建',
#    '1階',
#    '15万円',
#    '-',
#    '15万円',
#    '15万円',
#    '4K',
#    '73.75m2',
#    'https://suumo.jp/chintai/jnc_000086740977/?bc=100355480324'],),
#  (['賃貸マンション',
#    'ＪＲ中央線 東中野駅 3階建 築33年',
#    '東京都新宿区北新宿３',
#    'ＪＲ中央線/東中野駅 歩7分',
#    '東京メトロ丸ノ内線/中野坂上駅 歩13分',
#    '東京メトロ東西線/落合駅 歩15分',
#    '築33年',
#    '3階建',
#    '1階',
#    '19万円',
#    '10000円',
#    '-',
#    '19万円',
#    '4SK',
#    '80m2',
#    'https://suumo.jp/chintai/jnc_000086029265/?bc=100350767737'],),
#  (['賃貸マンション',
#    'kinomori代々木上原',
#    '東京都渋谷区上原２',
#    '東京メトロ千代田線/代々木公園駅 歩9分',
#    '小田急線/代々木八幡駅 歩8分',
#    '小田急線/代々木上原駅 歩7分',
#    '築1年',
#    '4階建',
#    '4階',
#    '12.7万円',
#    '10000円',
#    '-',
#    '-',
#    '2K',
#    '23.7m2',
#    'https://suumo.jp/chintai/jnc_000086724239/?bc=100355492530'],),
#  (['賃貸マンション',
#    'kinomori代々木上原',
#    '東京都渋谷区上原２',
#    '東京メトロ千代田線/代々木公園駅 歩9分',
#    '小田急線/代々木八幡駅 歩8分',
#    '小田急線/代々木上原駅 歩7分',
#    '築1年',
#    '4階建',
#    '1階',
#    '13万円',
#    '10000円',
#    '-',
#    '-',
#    '2K',
#    '24.08m2',
#    'https://suumo.jp/chintai/jnc_000086724226/?bc=100355659185'],),
#  (['賃貸マンション',
#    'kinomori代々木上原',
#    '東京都渋谷区上原２',
#    '東京メトロ千代田線/代々木公園駅 歩9分',
#    '小田急線/代々木八幡駅 歩8分',
#    '小田急線/代々木上原駅 歩7分',
#    '築1年',
#    '4階建',
#    '2階',
#    '13.1万円',
#    '10000円',
#    '-',
#    '-',
#    '2K',
#    '24.08m2',
#    'https://suumo.jp/chintai/jnc_000086724228/?bc=100355659193'],),
#  (['賃貸マンション',
#    'kinomori代々木上原',
#    '東京都渋谷区上原２',
#    '東京メトロ千代田線/代々木公園駅 歩9分',
#    '小田急線/代々木八幡駅 歩8分',
#    '小田急線/代々木上原駅 歩7分',
#    '築1年',
#    '4階建',
#    '3階',
#    '13.2万円',
#    '10000円',
#    '-',
#    '-',
#    '2K',
#    '24.08m2',
#    'https://suumo.jp/chintai/jnc_000086724231/?bc=100355659197'],),
#  (['賃貸マンション',
#    'kinomori代々木上原',
#    '東京都渋谷区上原２',
#    '東京メトロ千代田線/代々木公園駅 歩9分',
#    '小田急線/代々木八幡駅 歩8分',
#    '小田急線/代々木上原駅 歩7分',
#    '築1年',
#    '4階建',
#    '1階',
#    '14.3万円',
#    '10000円',
#    '-',
#    '-',
#    '2K',
#    '27.5m2',
#    'https://suumo.jp/chintai/jnc_000086724227/?bc=100355645130'],),
#  (['賃貸マンション',
#    'kinomori代々木上原',
#    '東京都渋谷区上原２',
#    '東京メトロ千代田線/代々木公園駅 歩9分',
#    '小田急線/代々木八幡駅 歩8分',
#    '小田急線/代々木上原駅 歩7分',
#    '築1年',
#    '4階建',
#    '2階',
#    '14.4万円',
#    '10000円',
#    '-',
#    '-',
#    '2K',
#    '27.5m2',
#    'https://suumo.jp/chintai/jnc_000086724229/?bc=100355659322'],),
#  (['賃貸マンション',
#    'kinomori代々木上原',
#    '東京都渋谷区上原２',
#    '東京メトロ千代田線/代々木公園駅 歩9分',
#    '小田急線/代々木八幡駅 歩8分',
#    '小田急線/代々木上原駅 歩7分',
#    '築1年',
#    '4階建',
#    '3階',
#    '14.5万円',
#    '10000円',
#    '-',
#    '-',
#    '2K',
#    '27.5m2',
#    'https://suumo.jp/chintai/jnc_000086724234/?bc=100355659168'],),
#  (['賃貸マンション',
#    'kinomori代々木上原',
#    '東京都渋谷区上原２',
#    '東京メトロ千代田線/代々木公園駅 歩9分',
#    '小田急線/代々木八幡駅 歩8分',
#    '小田急線/代々木上原駅 歩7分',
#    '築1年',
#    '4階建',
#    '3階',
#    '16万円',
#    '10000円',
#    '-',
#    '-',
#    '2K',
#    '30.24m2',
#    'https://suumo.jp/chintai/jnc_000086724230/?bc=100355659333'],),
#  (['賃貸マンション',
#    'kinomori代々木上原',
#    '東京都渋谷区上原２',
#    '東京メトロ千代田線/代々木公園駅 歩9分',
#    '小田急線/代々木八幡駅 歩8分',
#    '小田急線/代々木上原駅 歩7分',
#    '築1年',
#    '4階建',
#    '3階',
#    '16.2万円',
#    '10000円',
#    '-',
#    '-',
#    '2K',
#    '31.3m2',
#    'https://suumo.jp/chintai/jnc_000086724233/?bc=100355659340'],),
#  (['賃貸マンション',
#    'kinomori代々木上原',
#    '東京都渋谷区上原２',
#    '東京メトロ千代田線/代々木公園駅 歩9分',
#    '小田急線/代々木八幡駅 歩8分',
#    '小田急線/代々木上原駅 歩7分',
#    '築1年',
#    '4階建',
#    '4階',
#    '19万円',
#    '10000円',
#    '-',
#    '-',
#    '3K',
#    '35.5m2',
#    'https://suumo.jp/chintai/jnc_000086724238/?bc=100355659171'],),
#  (['賃貸マンション',
#    '東京メトロ千代田線 代々木公園駅 4階建 築1年',
#    '東京都渋谷区上原２',
#    '東京メトロ千代田線/代々木公園駅 歩9分',
#    '小田急線/代々木八幡駅 歩8分',
#    '小田急線/代々木上原駅 歩7分',
#    '築1年',
#    '4階建',
#    '4階',
#    '12.7万円',
#    '10000円',
#    '-',
#    '-',
#    '2K',
#    '23.7m2',
#    'https://suumo.jp/chintai/jnc_000086747408/?bc=100355532153'],),
#  (['賃貸マンション',
#    '東京メトロ千代田線 代々木公園駅 4階建 築1年',
#    '東京都渋谷区上原２',
#    '東京メトロ千代田線/代々木公園駅 歩9分',
#    '小田急線/代々木八幡駅 歩8分',
#    '小田急線/代々木上原駅 歩7分',
#    '築1年',
#    '4階建',
#    '1階',
#    '13万円',
#    '10000円',
#    '-',
#    '-',
#    '2K',
#    '24.08m2',
#    'https://suumo.jp/chintai/jnc_000086758400/?bc=100355659234'],),
#  (['賃貸マンション',
#    '東京メトロ千代田線 代々木公園駅 4階建 築1年',
#    '東京都渋谷区上原２',
#    '東京メトロ千代田線/代々木公園駅 歩9分',
#    '小田急線/代々木八幡駅 歩8分',
#    '小田急線/代々木上原駅 歩7分',
#    '築1年',
#    '4階建',
#    '2階',
#    '13.1万円',
#    '10000円',
#    '-',
#    '-',
#    '2K',
#    '24.08m2',
#    'https://suumo.jp/chintai/jnc_000086758401/?bc=100355659241'],),
#  (['賃貸マンション',
#    '東京メトロ千代田線 代々木公園駅 4階建 築1年',
#    '東京都渋谷区上原２',
#    '東京メトロ千代田線/代々木公園駅 歩9分',
#    '小田急線/代々木八幡駅 歩8分',
#    '小田急線/代々木上原駅 歩7分',
#    '築1年',
#    '4階建',
#    '3階',
#    '13.2万円',
#    '10000円',
#    '-',
#    '-',
#    '2K',
#    '24.08m2',
#    'https://suumo.jp/chintai/jnc_000086767985/?bc=100355659251'],),
#  (['賃貸マンション',
#    '東京メトロ千代田線 代々木公園駅 4階建 築1年',
#    '東京都渋谷区上原２',
#    '東京メトロ千代田線/代々木公園駅 歩9分',
#    '小田急線/代々木八幡駅 歩8分',
#    '小田急線/代々木上原駅 歩7分',
#    '築1年',
#    '4階建',
#    '2階',
#    '14.4万円',
#    '10000円',
#    '-',
#    '-',
#    '2K',
#    '27.5m2',
#    'https://suumo.jp/chintai/jnc_000086767982/?bc=100355659208'],),
#  (['賃貸マンション',
#    '東京メトロ千代田線 代々木公園駅 4階建 築1年',
#    '東京都渋谷区上原２',
#    '東京メトロ千代田線/代々木公園駅 歩9分',
#    '小田急線/代々木八幡駅 歩8分',
#    '小田急線/代々木上原駅 歩7分',
#    '築1年',
#    '4階建',
#    '3階',
#    '14.5万円',
#    '10000円',
#    '-',
#    '-',
#    '2K',
#    '27.5m2',
#    'https://suumo.jp/chintai/jnc_000086767988/?bc=100355659210'],),
#  (['賃貸マンション',
#    '東京メトロ千代田線 代々木公園駅 4階建 築1年',
#    '東京都渋谷区上原２',
#    '東京メトロ千代田線/代々木公園駅 歩9分',
#    '小田急線/代々木八幡駅 歩8分',
#    '小田急線/代々木上原駅 歩7分',
#    '築1年',
#    '4階建',
#    '3階',
#    '16万円',
#    '10000円',
#    '-',
#    '-',
#    '2K',
#    '30.24m2',
#    'https://suumo.jp/chintai/jnc_000086767984/?bc=100355659236'],),
#  (['賃貸マンション',
#    '東京メトロ千代田線 代々木公園駅 4階建 築1年',
#    '東京都渋谷区上原２',
#    '東京メトロ千代田線/代々木公園駅 歩9分',
#    '小田急線/代々木八幡駅 歩8分',
#    '小田急線/代々木上原駅 歩7分',
#    '築1年',
#    '4階建',
#    '3階',
#    '16.2万円',
#    '10000円',
#    '-',
#    '-',
#    '2K',
#    '31.3m2',
#    'https://suumo.jp/chintai/jnc_000086767987/?bc=100355659253'],),
#  (['賃貸マンション',
#    '東京メトロ千代田線 代々木公園駅 4階建 築1年',
#    '東京都渋谷区上原２',
#    '東京メトロ千代田線/代々木公園駅 歩9分',
#    '小田急線/代々木八幡駅 歩8分',
#    '小田急線/代々木上原駅 歩7分',
#    '築1年',
#    '4階建',
#    '4階',
#    '19万円',
#    '10000円',
#    '-',
#    '-',
#    '3K',
#    '35.5m2',
#    'https://suumo.jp/chintai/jnc_000086767990/?bc=100355659213'],),
#  (['賃貸マンション',
#    'ガーラ・プレシャス練馬',
#    '東京都練馬区豊玉北３',
#    '都営大江戸線/練馬駅 歩10分',
#    '西武池袋線/桜台駅 歩5分',
#    '都営大江戸線/新江古田駅 歩12分',
#    '築5年',
#    '7階建',
#    '2階',
#    '8.7万円',
#    '9000円',
#    '8.7万円',
#    '17.4万円',
#    '2K',
#    '25.8m2',
#    'https://suumo.jp/chintai/jnc_000049706530/?bc=100354987821'],),
#  (['賃貸マンション',
#    'ガーラ・プレシャス練馬',
#    '東京都練馬区豊玉北３',
#    '都営大江戸線/練馬駅 歩10分',
#    '西武池袋線/桜台駅 歩5分',
#    '都営大江戸線/新江古田駅 歩12分',
#    '築5年',
#    '7階建',
#    '2階',
#    '8.7万円',
#    '9000円',
#    '8.7万円',
#    '17.4万円',
#    '2K',
#    '25.8m2',
#    'https://suumo.jp/chintai/jnc_000064337073/?bc=100355153480'],),
#  (['賃貸マンション',
#    'ガーラ・プレシャス練馬',
#    '東京都練馬区豊玉北３',
#    '都営大江戸線/練馬駅 歩10分',
#    '西武池袋線/桜台駅 歩5分',
#    '都営大江戸線/新江古田駅 歩12分',
#    '築5年',
#    '7階建',
#    '3階',
#    '8.75万円',
#    '9000円',
#    '8.75万円',
#    '17.5万円',
#    '2K',
#    '25.8m2',
#    'https://suumo.jp/chintai/jnc_000050575859/?bc=100353058611'],),
#  (['賃貸マンション',
#    'ガーラ・プレシャス練馬',
#    '東京都練馬区豊玉北３',
#    '都営大江戸線/練馬駅 歩10分',
#    '西武池袋線/桜台駅 歩5分',
#    '都営大江戸線/新江古田駅 歩12分',
#    '築5年',
#    '7階建',
#    '3階',
#    '8.75万円',
#    '9000円',
#    '8.75万円',
#    '17.5万円',
#    '2K',
#    '25.8m2',
#    'https://suumo.jp/chintai/jnc_000051293955/?bc=100353270281'],),
#  (['賃貸マンション',
#    'ガーラ・プレシャス練馬',
#    '東京都練馬区豊玉北３',
#    '都営大江戸線/練馬駅 歩10分',
#    '西武池袋線/桜台駅 歩5分',
#    '都営大江戸線/新江古田駅 歩12分',
#    '築5年',
#    '7階建',
#    '3階',
#    '8.75万円',
#    '9000円',
#    '8.75万円',
#    '17.5万円',
#    '2K',
#    '25.8m2',
#    'https://suumo.jp/chintai/jnc_000051262324/?bc=100353199078'],),
#  (['賃貸マンション',
#    'ガーラ・プレシャス練馬',
#    '東京都練馬区豊玉北３',
#    '都営大江戸線/練馬駅 歩10分',
#    '西武池袋線/桜台駅 歩5分',
#    '都営大江戸線/新江古田駅 歩12分',
#    '築5年',
#    '7階建',
#    '3階',
#    '9.7万円',
#    '10000円',
#    '9.7万円',
#    '19.4万円',
#    '2K',
#    '28.41m2',
#    'https://suumo.jp/chintai/jnc_000086659736/?bc=100354987794'],),
#  (['賃貸マンション',
#    'きんえいマンション',
#    '東京都練馬区豊玉上２',
#    '西武池袋線/桜台駅 歩5分',
#    '西武池袋線/練馬駅 歩7分',
#    '都営大江戸線/練馬駅 歩7分',
#    '築40年',
#    '8階建',
#    '2階',
#    '12万円',
#    '8000円',
#    '12万円',
#    '12万円',
#    '3DK',
#    '55m2',
#    'https://suumo.jp/chintai/jnc_000086768309/?bc=100355704432'],),
#  (['賃貸マンション',
#    'きんえいマンション',
#    '東京都練馬区豊玉上２',
#    '西武池袋線/桜台駅 歩5分',
#    '西武池袋線/練馬駅 歩7分',
#    '都営大江戸線/練馬駅 歩7分',
#    '築40年',
#    '8階建',
#    '8階',
#    '12.2万円',
#    '8000円',
#    '12.2万円',
#    '12.2万円',
#    '3DK',
#    '55m2',
#    'https://suumo.jp/chintai/jnc_000085810472/?bc=100350556876'],),
#  (['賃貸マンション',
#    'プレジオ戸越',
#    '東京都品川区平塚１',
#    '東急池上線/戸越銀座駅 歩1分',
#    '都営浅草線/戸越駅 歩2分',
#    '東急池上線/荏原中延駅 歩10分',
#    '築24年',
#    '3階建',
#    '2階',
#    '13.8万円',
#    '5000円',
#    '13.8万円',
#    '13.8万円',
#    '2K',
#    '43.45m2',
#    'https://suumo.jp/chintai/jnc_000086740464/?bc=100355680061'],),
#  (['賃貸マンション',
#    '東急池上線 戸越銀座駅 3階建 築24年',
#    '東京都品川区平塚１',
#    '東急池上線/戸越銀座駅 歩1分',
#    '都営浅草線/戸越駅 歩1分',
#    '東急目黒線/武蔵小山駅 歩18分',
#    '築24年',
#    '3階建',
#    '2階',
#    '13.8万円',
#    '5000円',
#    '13.8万円',
#    '13.8万円',
#    '2K',
#    '43.45m2',
#    'https://suumo.jp/chintai/jnc_000086758229/?bc=100355604893'],),
#  (['賃貸マンション',
#    'ZOOM高田馬場',
#    '東京都新宿区下落合１',
#    '西武新宿線/下落合駅 歩5分',
#    'ＪＲ山手線/高田馬場駅 歩9分',
#    '都営大江戸線/中井駅 歩16分',
#    '築2年',
#    '10階建',
#    '2階',
#    '13.3万円',
#    '8000円',
#    '13.3万円',
#    '13.3万円',
#    '2K',
#    '32.68m2',
#    'https://suumo.jp/chintai/jnc_000071224222/?bc=100355620175'],),
#  (['賃貸一戸建て',
#    '足立区柳原2丁目貸戸建',
#    '東京都足立区柳原２',
#    'ＪＲ常磐線/北千住駅 歩10分',
#    '東武伊勢崎線/牛田駅 歩10分',
#    '京成本線/京成関屋駅 歩10分',
#    '築36年',
#    '2階建',
#    '1階',
#    '11万円',
#    '-',
#    '11万円',
#    '11万円',
#    '4DK',
#    '70m2',
#    'https://suumo.jp/chintai/jnc_000083935323/?bc=100337398126'],),
#  (['賃貸一戸建て',
#    '足立区柳原2丁目貸戸建',
#    '東京都足立区柳原２',
#    'ＪＲ常磐線/北千住駅 歩10分',
#    '東武伊勢崎線/牛田駅 歩10分',
#    '京成本線/京成関屋駅 歩10分',
#    '築36年',
#    '2階建',
#    '1-2階',
#    '11万円',
#    '-',
#    '11万円',
#    '11万円',
#    '4DK',
#    '70m2',
#    'https://suumo.jp/chintai/jnc_000086021814/?bc=100350707681'],),
#  (['賃貸一戸建て',
#    'ＪＲ京浜東北線 蒲田駅 2階建 築42年',
#    '東京都大田区蒲田１',
#    'ＪＲ京浜東北線/蒲田駅 歩9分',
#    '京急空港線/京急蒲田駅 歩9分',
#    '京急本線/梅屋敷駅 歩10分',
#    '築42年',
#    '2階建',
#    '1-2階',
#    '17万円',
#    '-',
#    '17万円',
#    '17万円',
#    '5LDK',
#    '132m2',
#    'https://suumo.jp/chintai/jnc_000031694514/?bc=100355058819'],),
#  (['賃貸一戸建て',
#    '西ヶ原ハウスIII',
#    '東京都北区西ケ原２',
#    '東京メトロ南北線/西ケ原駅 歩4分',
#    'ＪＲ京浜東北線/王子駅 歩7分',
#    '都電荒川線/飛鳥山駅 歩6分',
#    '築53年',
#    '2階建',
#    '-',
#    '16万円',
#    '-',
#    '16万円',
#    '16万円',
#    '4DK',
#    '67.47m2',
#    'https://suumo.jp/chintai/jnc_000078675788/?bc=100355496653'],),
#  (['賃貸マンション',
#    'アヴァンティーク東銀座',
#    '東京都中央区築地４',
#    '都営大江戸線/築地市場駅 歩1分',
#    '都営浅草線/東銀座駅 歩3分',
#    '東京メトロ日比谷線/築地駅 歩5分',
#    '築20年',
#    '8階建',
#    '4階',
#    '15.1万円',
#    '9000円',
#    '15.1万円',
#    '15.1万円',
#    '3K',
#    '41.46m2',
#    'https://suumo.jp/chintai/jnc_000043005108/?bc=100355229981'],),
#  (['賃貸マンション',
#    '東京メトロ日比谷線 東銀座駅 8階建 築20年',
#    '東京都中央区築地４',
#    '東京メトロ日比谷線/東銀座駅 歩3分',
#    '都営大江戸線/築地市場駅 歩5分',
#    '東京メトロ日比谷線/築地駅 歩6分',
#    '築20年',
#    '8階建',
#    '4階',
#    '15.1万円',
#    '9000円',
#    '15.1万円',
#    '15.1万円',
#    '2SK',
#    '41.46m2',
#    'https://suumo.jp/chintai/jnc_000043019091/?bc=100355225016'],),
#  (['賃貸マンション',
#    'フレンシア御徒町',
#    '東京都台東区東上野１',
#    '東京メトロ日比谷線/仲御徒町駅 歩3分',
#    'ＪＲ山手線/御徒町駅 歩5分',
#    '都営大江戸線/上野御徒町駅 歩6分',
#    '新築',
#    '13階建',
#    '2階',
#    '18.3万円',
#    '14000円',
#    '18.3万円',
#    '18.3万円',
#    '2LDK',
#    '40.47m2',
#    'https://suumo.jp/chintai/jnc_000086740252/?bc=100355450743'],),
#  (['賃貸マンション',
#    'フレンシア御徒町',
#    '東京都台東区東上野１',
#    '東京メトロ日比谷線/仲御徒町駅 歩3分',
#    'ＪＲ山手線/御徒町駅 歩5分',
#    '都営大江戸線/上野御徒町駅 歩6分',
#    '新築',
#    '13階建',
#    '2階',
#    '18.4万円',
#    '14000円',
#    '18.4万円',
#    '18.4万円',
#    '2LDK',
#    '41.61m2',
#    'https://suumo.jp/chintai/jnc_000086740249/?bc=100355475244'],),
#  (['賃貸マンション',
#    'フレンシア御徒町',
#    '東京都台東区東上野１',
#    '東京メトロ日比谷線/仲御徒町駅 歩3分',
#    'ＪＲ山手線/御徒町駅 歩5分',
#    '都営大江戸線/上野御徒町駅 歩6分',
#    '新築',
#    '13階建',
#    '3階',
#    '18.5万円',
#    '14000円',
#    '18.5万円',
#    '18.5万円',
#    '2LDK',
#    '40.47m2',
#    'https://suumo.jp/chintai/jnc_000086740260/?bc=100355637013'],),
#  (['賃貸マンション',
#    'フレンシア御徒町',
#    '東京都台東区東上野１',
#    '東京メトロ日比谷線/仲御徒町駅 歩3分',
#    'ＪＲ山手線/御徒町駅 歩5分',
#    '都営大江戸線/上野御徒町駅 歩6分',
#    '新築',
#    '13階建',
#    '3階',
#    '18.6万円',
#    '14000円',
#    '18.6万円',
#    '18.6万円',
#    '2LDK',
#    '41.61m2',
#    'https://suumo.jp/chintai/jnc_000086740257/?bc=100355450771'],),
#  (['賃貸マンション',
#    '東京メトロ半蔵門線 水天宮前駅 12階建 築26年',
#    '東京都中央区日本橋中洲',
#    '東京メトロ半蔵門線/水天宮前駅 歩6分',
#    '都営新宿線/浜町駅 歩8分',
#    '東京メトロ日比谷線/人形町駅 歩9分',
#    '築26年',
#    '12階建',
#    '5階',
#    '17.1万円',
#    '12000円',
#    '17.1万円',
#    '-',
#    '2LDK',
#    '53.69m2',
#    'https://suumo.jp/chintai/jnc_000074737168/?bc=100355610644'],),
#  (['賃貸マンション',
#    'リヴ赤塚',
#    '東京都板橋区赤塚２',
#    '東武東上線/成増駅 歩8分',
#    '東京メトロ副都心線/地下鉄赤塚駅 歩7分',
#    '東京メトロ有楽町線/地下鉄成増駅 歩11分',
#    '築16年',
#    '3階建',
#    '1階',
#    '12万円',
#    '6000円',
#    '12万円',
#    '12万円',
#    '2LDK',
#    '52.25m2',
#    'https://suumo.jp/chintai/jnc_000086732326/?bc=100320968714'],),
#  (['賃貸テラス・タウンハウス',
#    'カーサ・ロテリア',
#    '東京都豊島区千早３',
#    '西武池袋線/東長崎駅 歩7分',
#    '東京メトロ有楽町線/千川駅 歩10分',
#    '東京メトロ副都心線/千川駅 歩10分',
#    '築11年',
#    '2階建',
#    '2階',
#    '15.8万円',
#    '-',
#    '15.8万円',
#    '23.7万円',
#    '2LDK',
#    '62.92m2',
#    'https://suumo.jp/chintai/jnc_000048112047/?bc=100355467800'],),
#  (['賃貸マンション',
#    '東京メトロ日比谷線 三ノ輪駅 11階建 築46年',
#    '東京都荒川区荒川１',
#    '東京メトロ日比谷線/三ノ輪駅 歩9分',
#    '都電荒川線/荒川区役所前駅 歩2分',
#    '',
#    '築46年',
#    '11階建',
#    '11階',
#    '9.5万円',
#    '-',
#    '9.5万円',
#    '9.5万円',
#    '3K',
#    '41.26m2',
#    'https://suumo.jp/chintai/jnc_000045513888/?bc=100325902258'],),
#  (['賃貸マンション',
#    'シャンボール三ノ輪',
#    '東京都荒川区荒川１',
#    '東京メトロ日比谷線/三ノ輪駅 歩9分',
#    'ＪＲ常磐線/三河島駅 歩12分',
#    '京成本線/町屋駅 歩15分',
#    '築46年',
#    '11階建',
#    '11階',
#    '9.5万円',
#    '-',
#    '9.5万円',
#    '9.5万円',
#    '3K',
#    '41.26m2',
#    'https://suumo.jp/chintai/jnc_000036748255/?bc=100325590863'],),
#  (['賃貸マンション',
#    'ＪＲ山手線 五反田駅 8階建 築54年',
#    '東京都品川区東五反田２',
#    'ＪＲ山手線/五反田駅 歩3分',
#    '都営浅草線/五反田駅 歩3分',
#    '東急池上線/五反田駅 歩3分',
#    '築54年',
#    '8階建',
#    '2階',
#    '12.9万円',
#    '10000円',
#    '12.9万円',
#    '12.9万円',
#    '2DK',
#    '42.89m2',
#    'https://suumo.jp/chintai/jnc_000086341919/?bc=100352861039'],),
#  (['賃貸アパート',
#    'シティパオ荻窪',
#    '東京都杉並区荻窪４',
#    'ＪＲ中央線/荻窪駅 歩4分',
#    'ＪＲ総武線/荻窪駅 歩4分',
#    '東京メトロ丸ノ内線/荻窪駅 歩4分',
#    '築32年',
#    '2階建',
#    '1階',
#    '14.2万円',
#    '3000円',
#    '14.2万円',
#    '14.2万円',
#    '2DK',
#    '42.04m2',
#    'https://suumo.jp/chintai/jnc_000057975491/?bc=100355673822'],),
#  (['賃貸マンション',
#    'サン・コート井草',
#    '東京都杉並区井草１',
#    '西武新宿線/下井草駅 歩3分',
#    '西武池袋線/富士見台駅 歩21分',
#    'ＪＲ中央線/荻窪駅 バス22分 (バス停)下井草駅 歩5分',
#    '築41年',
#    '4階建',
#    '2階',
#    '15.3万円',
#    '7000円',
#    '-',
#    '-',
#    '4DK',
#    '83.38m2',
#    'https://suumo.jp/chintai/jnc_000084095175/?bc=100353731736'],),
#  (['賃貸マンション',
#    'サン・コート井草',
#    '東京都杉並区井草１',
#    '西武新宿線/下井草駅 歩3分',
#    '西武池袋線/富士見台駅 歩21分',
#    'ＪＲ中央線/荻窪駅 バス22分 (バス停)下井草駅 歩5分',
#    '築41年',
#    '4階建',
#    '2階',
#    '15.8万円',
#    '7000円',
#    '-',
#    '15.8万円',
#    '4DK',
#    '83.38m2',
#    'https://suumo.jp/chintai/jnc_000086651340/?bc=100338504190'],),
#  (['賃貸マンション',
#    '東京メトロ丸ノ内線 四谷三丁目駅 10階建 築4年',
#    '東京都新宿区大京町',
#    '東京メトロ丸ノ内線/四谷三丁目駅 歩7分',
#    '都営大江戸線/国立競技場駅 歩10分',
#    '都営新宿線/曙橋駅 歩15分',
#    '築4年',
#    '10階建',
#    '2階',
#    '13.15万円',
#    '10000円',
#    '-',
#    '-',
#    '21K',
#    '25.59m2',
#    'https://suumo.jp/chintai/jnc_000086583922/?bc=100354429067'],),
#  (['賃貸マンション',
#    '西武新宿線 下井草駅 4階建 築41年',
#    '東京都杉並区井草１',
#    '西武新宿線/下井草駅 歩3分',
#    '西武新宿線/井荻駅 歩7分',
#    '西武池袋線/富士見台駅 歩20分',
#    '築41年',
#    '4階建',
#    '2階',
#    '15.8万円',
#    '7000円',
#    '-',
#    '15.8万円',
#    '4DK',
#    '83.38m2',
#    'https://suumo.jp/chintai/jnc_000086651341/?bc=100351770928'],),
#  (['賃貸マンション',
#    '西武新宿線 下井草駅 4階建 築41年',
#    '東京都杉並区井草１',
#    '西武新宿線/下井草駅 歩3分',
#    '西武新宿線/井荻駅 歩7分',
#    '西武池袋線/富士見台駅 歩20分',
#    '築41年',
#    '4階建',
#    '2階',
#    '15.8万円',
#    '7000円',
#    '-',
#    '15.8万円',
#    '4DK',
#    '83.38m2',
#    'https://suumo.jp/chintai/jnc_000086667014/?bc=100338626587'],),
#  (['賃貸マンション',
#    'メゾン・ド・ヴィオレ',
#    '東京都大田区東矢口３',
#    '東急池上線/蓮沼駅 歩6分',
#    '東急多摩川線/矢口渡駅 歩9分',
#    '東急多摩川線/蒲田駅 歩10分',
#    '築29年',
#    '4階建',
#    '4階',
#    '12万円',
#    '5000円',
#    '12万円',
#    '12万円',
#    '2DK',
#    '40.46m2',
#    'https://suumo.jp/chintai/jnc_000086423628/?bc=100353322313'],),
#  (['賃貸マンション',
#    'ＪＲ京浜東北線 蒲田駅 4階建 築29年',
#    '東京都大田区東矢口３',
#    'ＪＲ京浜東北線/蒲田駅 歩10分',
#    '東急池上線/蓮沼駅 歩4分',
#    '東急多摩川線/矢口渡駅 歩8分',
#    '築29年',
#    '4階建',
#    '4階',
#    '12万円',
#    '5000円',
#    '12万円',
#    '12万円',
#    '2DK',
#    '40.46m2',
#    'https://suumo.jp/chintai/jnc_000086758304/?bc=100355602629'],),
#  (['賃貸マンション',
#    'ＪＲ京浜東北線 赤羽駅 4階建 築31年',
#    '東京都北区赤羽１',
#    'ＪＲ京浜東北線/赤羽駅 歩7分',
#    '東京メトロ南北線/赤羽岩淵駅 歩3分',
#    '東京メトロ南北線/志茂駅 歩17分',
#    '築31年',
#    '4階建',
#    '2階',
#    '11.5万円',
#    '-',
#    '11.5万円',
#    '-',
#    '3K',
#    '46.92m2',
#    'https://suumo.jp/chintai/jnc_000061088020/?bc=100336074082'],),
#  (['賃貸マンション',
#    '要町ガーデンハイツ',
#    '東京都豊島区要町１',
#    '東京メトロ副都心線/要町駅 歩5分',
#    '東京メトロ有楽町線/要町駅 歩5分',
#    '西武池袋線/椎名町駅 歩12分',
#    '築32年',
#    '5階建',
#    '3階',
#    '17.8万円',
#    '10000円',
#    '17.8万円',
#    '21.36万円',
#    '2LDK',
#    '59.85m2',
#    'https://suumo.jp/chintai/jnc_000085324912/?bc=100342155569'],),
#  (['賃貸マンション',
#    'フジハイツ',
#    '東京都品川区中延６',
#    '東急大井町線/荏原町駅 歩7分',
#    '都営浅草線/馬込駅 歩8分',
#    '東急大井町線/中延駅 歩10分',
#    '築40年',
#    '3階建',
#    '3階',
#    '10万円',
#    '-',
#    '10万円',
#    '-',
#    '3K',
#    '49m2',
#    'https://suumo.jp/chintai/jnc_000083785065/?bc=100336451160'],),
#  (['賃貸マンション',
#    'ザ・プレミアムキューブG東中野',
#    '東京都中野区東中野５',
#    'ＪＲ中央線/東中野駅 歩7分',
#    '東京メトロ東西線/落合駅 歩7分',
#    'ＪＲ山手線/高田馬場駅 歩21分',
#    '新築',
#    '5階建',
#    '1階',
#    '11.35万円',
#    '15000円',
#    '-',
#    '11.35万円',
#    '2K',
#    '25.5m2',
#    'https://suumo.jp/chintai/jnc_000085010262/?bc=100351426330'],),
#  (['賃貸マンション',
#    'ザ・プレミアムキューブG東中野',
#    '東京都中野区東中野５',
#    'ＪＲ中央線/東中野駅 歩7分',
#    '東京メトロ東西線/落合駅 歩7分',
#    'ＪＲ山手線/高田馬場駅 歩21分',
#    '新築',
#    '5階建',
#    '1階',
#    '11.4万円',
#    '15000円',
#    '-',
#    '11.4万円',
#    '2K',
#    '25.98m2',
#    'https://suumo.jp/chintai/jnc_000086598490/?bc=100354729150'],),
#  (['賃貸マンション',
#    'ザ・プレミアムキューブG東中野',
#    '東京都中野区東中野５',
#    'ＪＲ中央線/東中野駅 歩7分',
#    '東京メトロ東西線/落合駅 歩7分',
#    'ＪＲ山手線/高田馬場駅 歩21分',
#    '新築',
#    '5階建',
#    '1階',
#    '11.4万円',
#    '15000円',
#    '-',
#    '11.4万円',
#    '2K',
#    '25.98m2',
#    'https://suumo.jp/chintai/jnc_000086598488/?bc=100354729147'],),
#  (['賃貸マンション',
#    'ザ・プレミアムキューブG東中野',
#    '東京都中野区東中野５',
#    'ＪＲ中央線/東中野駅 歩7分',
#    '東京メトロ東西線/落合駅 歩7分',
#    'ＪＲ山手線/高田馬場駅 歩21分',
#    '新築',
#    '5階建',
#    '1階',
#    '11.4万円',
#    '15000円',
#    '-',
#    '11.4万円',
#    '2K',
#    '25.98m2',
#    'https://suumo.jp/chintai/jnc_000085010248/?bc=100353316388'],),
#  (['賃貸マンション',
#    'ザ・プレミアムキューブG東中野',
#    '東京都中野区東中野５',
#    'ＪＲ中央線/東中野駅 歩7分',
#    '東京メトロ東西線/落合駅 歩7分',
#    'ＪＲ山手線/高田馬場駅 歩21分',
#    '新築',
#    '5階建',
#    '1階',
#    '11.4万円',
#    '15000円',
#    '-',
#    '11.4万円',
#    '2K',
#    '25.98m2',
#    'https://suumo.jp/chintai/jnc_000086598491/?bc=100354729152'],),
#  (['賃貸マンション',
#    'ザ・プレミアムキューブG東中野',
#    '東京都中野区東中野５',
#    'ＪＲ中央線/東中野駅 歩7分',
#    '東京メトロ東西線/落合駅 歩7分',
#    'ＪＲ山手線/高田馬場駅 歩21分',
#    '新築',
#    '5階建',
#    '1階',
#    '11.4万円',
#    '15000円',
#    '-',
#    '11.4万円',
#    '2K',
#    '25.98m2',
#    'https://suumo.jp/chintai/jnc_000086598489/?bc=100354729157'],),
#  (['賃貸マンション',
#    'ザ・プレミアムキューブG東中野',
#    '東京都中野区東中野５',
#    'ＪＲ中央線/東中野駅 歩7分',
#    '東京メトロ東西線/落合駅 歩7分',
#    'ＪＲ山手線/高田馬場駅 歩21分',
#    '新築',
#    '5階建',
#    '1階',
#    '11.4万円',
#    '15000円',
#    '-',
#    '11.4万円',
#    '2K',
#    '25.98m2',
#    'https://suumo.jp/chintai/jnc_000086598487/?bc=100354729160'],),
#  (['賃貸マンション',
#    'ザ・プレミアムキューブG東中野',
#    '東京都中野区東中野５',
#    'ＪＲ中央線/東中野駅 歩7分',
#    '東京メトロ東西線/落合駅 歩7分',
#    'ＪＲ山手線/高田馬場駅 歩21分',
#    '新築',
#    '5階建',
#    '2階',
#    '11.65万円',
#    '15000円',
#    '-',
#    '11.65万円',
#    '2K',
#    '25.9m2',
#    'https://suumo.jp/chintai/jnc_000086598494/?bc=100354729168'],),
#  (['賃貸マンション',
#    'ザ・プレミアムキューブG東中野',
#    '東京都中野区東中野５',
#    'ＪＲ中央線/東中野駅 歩7分',
#    '東京メトロ東西線/落合駅 歩7分',
#    'ＪＲ山手線/高田馬場駅 歩21分',
#    '新築',
#    '5階建',
#    '2階',
#    '11.65万円',
#    '15000円',
#    '-',
#    '11.65万円',
#    '2K',
#    '25.5m2',
#    'https://suumo.jp/chintai/jnc_000086376701/?bc=100353515532'],),
#  (['賃貸マンション',
#    'ザ・プレミアムキューブG東中野',
#    '東京都中野区東中野５',
#    'ＪＲ中央線/東中野駅 歩7分',
#    '東京メトロ東西線/落合駅 歩7分',
#    'ＪＲ山手線/高田馬場駅 歩21分',
#    '新築',
#    '5階建',
#    '2階',
#    '11.65万円',
#    '15000円',
#    '-',
#    '11.65万円',
#    '2K',
#    '25.5m2',
#    'https://suumo.jp/chintai/jnc_000086376700/?bc=100353515496'],),
#  (['賃貸マンション',
#    'ザ・プレミアムキューブG東中野',
#    '東京都中野区東中野５',
#    'ＪＲ中央線/東中野駅 歩7分',
#    '東京メトロ東西線/落合駅 歩7分',
#    'ＪＲ山手線/高田馬場駅 歩21分',
#    '新築',
#    '5階建',
#    '2階',
#    '11.7万円',
#    '15000円',
#    '-',
#    '11.7万円',
#    '2K',
#    '25.98m2',
#    'https://suumo.jp/chintai/jnc_000085010268/?bc=100351432870'],),
#  (['賃貸マンション',
#    'ザ・プレミアムキューブG東中野',
#    '東京都中野区東中野５',
#    'ＪＲ中央線/東中野駅 歩7分',
#    '東京メトロ東西線/落合駅 歩7分',
#    'ＪＲ山手線/高田馬場駅 歩21分',
#    '新築',
#    '5階建',
#    '2階',
#    '11.7万円',
#    '15000円',
#    '-',
#    '11.7万円',
#    '2K',
#    '25.98m2',
#    'https://suumo.jp/chintai/jnc_000085010269/?bc=100355042788'],),
#  (['賃貸マンション',
#    'ザ・プレミアムキューブG東中野',
#    '東京都中野区東中野５',
#    'ＪＲ中央線/東中野駅 歩7分',
#    '東京メトロ東西線/落合駅 歩7分',
#    'ＪＲ山手線/高田馬場駅 歩21分',
#    '新築',
#    '5階建',
#    '2階',
#    '11.7万円',
#    '15000円',
#    '-',
#    '11.7万円',
#    '2K',
#    '25.98m2',
#    'https://suumo.jp/chintai/jnc_000085010270/?bc=100351433097'],),
#  (['賃貸マンション',
#    'ザ・プレミアムキューブG東中野',
#    '東京都中野区東中野５',
#    'ＪＲ中央線/東中野駅 歩7分',
#    '東京メトロ東西線/落合駅 歩7分',
#    'ＪＲ山手線/高田馬場駅 歩21分',
#    '新築',
#    '5階建',
#    '2階',
#    '11.7万円',
#    '15000円',
#    '-',
#    '11.7万円',
#    '2K',
#    '25.98m2',
#    'https://suumo.jp/chintai/jnc_000085010271/?bc=100353919042'],),
#  (['賃貸マンション',
#    'ザ・プレミアムキューブG東中野',
#    '東京都中野区東中野５',
#    'ＪＲ中央線/東中野駅 歩7分',
#    '東京メトロ東西線/落合駅 歩7分',
#    'ＪＲ山手線/高田馬場駅 歩21分',
#    '新築',
#    '5階建',
#    '2階',
#    '11.7万円',
#    '15000円',
#    '-',
#    '11.7万円',
#    '2K',
#    '25.98m2',
#    'https://suumo.jp/chintai/jnc_000085010267/?bc=100351432974'],),
#  (['賃貸マンション',
#    'ザ・プレミアムキューブG東中野',
#    '東京都中野区東中野５',
#    'ＪＲ中央線/東中野駅 歩7分',
#    '東京メトロ東西線/落合駅 歩7分',
#    'ＪＲ山手線/高田馬場駅 歩21分',
#    '新築',
#    '5階建',
#    '2階',
#    '11.7万円',
#    '15000円',
#    '-',
#    '11.7万円',
#    '2K',
#    '25.9m2',
#    'https://suumo.jp/chintai/jnc_000085010281/?bc=100345787975'],),
#  (['賃貸マンション',
#    'ザ・プレミアムキューブG東中野',
#    '東京都中野区東中野５',
#    'ＪＲ中央線/東中野駅 歩7分',
#    '東京メトロ東西線/落合駅 歩7分',
#    'ＪＲ山手線/高田馬場駅 歩21分',
#    '新築',
#    '5階建',
#    '3階',
#    '11.7万円',
#    '15000円',
#    '-',
#    '11.7万円',
#    '2K',
#    '25.9m2',
#    'https://suumo.jp/chintai/jnc_000085010292/?bc=100345787938'],),
#  (['賃貸マンション',
#    'ザ・プレミアムキューブG東中野',
#    '東京都中野区東中野５',
#    'ＪＲ中央線/東中野駅 歩7分',
#    '東京メトロ東西線/落合駅 歩7分',
#    'ＪＲ山手線/高田馬場駅 歩21分',
#    '新築',
#    '5階建',
#    '3階',
#    '11.7万円',
#    '15000円',
#    '-',
#    '11.7万円',
#    '2K',
#    '25.5m2',
#    'https://suumo.jp/chintai/jnc_000085010290/?bc=100345787995'],),
#  (['賃貸マンション',
#    'ザ・プレミアムキューブG東中野',
#    '東京都中野区東中野５',
#    'ＪＲ中央線/東中野駅 歩7分',
#    '東京メトロ東西線/落合駅 歩7分',
#    'ＪＲ山手線/高田馬場駅 歩21分',
#    '新築',
#    '5階建',
#    '3階',
#    '11.7万円',
#    '15000円',
#    '-',
#    '11.7万円',
#    '2K',
#    '25.5m2',
#    'https://suumo.jp/chintai/jnc_000085010289/?bc=100345788010'],),
#  (['賃貸マンション',
#    'ザ・プレミアムキューブG東中野',
#    '東京都中野区東中野５',
#    'ＪＲ中央線/東中野駅 歩7分',
#    '東京メトロ東西線/落合駅 歩7分',
#    'ＪＲ山手線/高田馬場駅 歩21分',
#    '新築',
#    '5階建',
#    '3階',
#    '11.75万円',
#    '15000円',
#    '-',
#    '11.75万円',
#    '2K',
#    '25.98m2',
#    'https://suumo.jp/chintai/jnc_000086598497/?bc=100355137621'],),
#  (['賃貸マンション',
#    'ザ・プレミアムキューブG東中野',
#    '東京都中野区東中野５',
#    'ＪＲ中央線/東中野駅 歩7分',
#    '東京メトロ東西線/落合駅 歩7分',
#    'ＪＲ山手線/高田馬場駅 歩21分',
#    '新築',
#    '5階建',
#    '3階',
#    '11.75万円',
#    '15000円',
#    '-',
#    '11.75万円',
#    '2K',
#    '25.98m2',
#    'https://suumo.jp/chintai/jnc_000085010285/?bc=100345787958'],),
#  (['賃貸マンション',
#    'ザ・プレミアムキューブG東中野',
#    '東京都中野区東中野５',
#    'ＪＲ中央線/東中野駅 歩7分',
#    '東京メトロ東西線/落合駅 歩7分',
#    'ＪＲ山手線/高田馬場駅 歩21分',
#    '新築',
#    '5階建',
#    '3階',
#    '11.75万円',
#    '15000円',
#    '-',
#    '11.75万円',
#    '2K',
#    '25.98m2',
#    'https://suumo.jp/chintai/jnc_000086598499/?bc=100355137532'],),
#  (['賃貸マンション',
#    'ザ・プレミアムキューブG東中野',
#    '東京都中野区東中野５',
#    'ＪＲ中央線/東中野駅 歩7分',
#    '東京メトロ東西線/落合駅 歩7分',
#    'ＪＲ山手線/高田馬場駅 歩21分',
#    '新築',
#    '5階建',
#    '3階',
#    '11.75万円',
#    '15000円',
#    '-',
#    '11.75万円',
#    '2K',
#    '25.98m2',
#    'https://suumo.jp/chintai/jnc_000086598498/?bc=100355137561'],),
#  (['賃貸マンション',
#    'ザ・プレミアムキューブG東中野',
#    '東京都中野区東中野５',
#    'ＪＲ中央線/東中野駅 歩7分',
#    '東京メトロ東西線/落合駅 歩7分',
#    'ＪＲ山手線/高田馬場駅 歩21分',
#    '新築',
#    '5階建',
#    '3階',
#    '11.75万円',
#    '15000円',
#    '-',
#    '11.75万円',
#    '2K',
#    '25.98m2',
#    'https://suumo.jp/chintai/jnc_000086598500/?bc=100355137547'],),
#  (['賃貸マンション',
#    'ザ・プレミアムキューブG東中野',
#    '東京都中野区東中野５',
#    'ＪＲ中央線/東中野駅 歩7分',
#    '東京メトロ東西線/落合駅 歩7分',
#    'ＪＲ山手線/高田馬場駅 歩21分',
#    '新築',
#    '5階建',
#    '3階',
#    '11.75万円',
#    '15000円',
#    '-',
#    '11.75万円',
#    '2K',
#    '25.98m2',
#    'https://suumo.jp/chintai/jnc_000085010284/?bc=100345787976'],),
#  (['賃貸マンション',
#    'ザ・プレミアムキューブG東中野',
#    '東京都中野区東中野５',
#    'ＪＲ中央線/東中野駅 歩7分',
#    '東京メトロ東西線/落合駅 歩7分',
#    'ＪＲ山手線/高田馬場駅 歩21分',
#    '新築',
#    '5階建',
#    '4階',
#    '11.75万円',
#    '15000円',
#    '-',
#    '11.75万円',
#    '2K',
#    '25.9m2',
#    'https://suumo.jp/chintai/jnc_000085010318/?bc=100345788008'],),
#  (['賃貸マンション',
#    'ザ・プレミアムキューブG東中野',
#    '東京都中野区東中野５',
#    'ＪＲ中央線/東中野駅 歩7分',
#    '東京メトロ東西線/落合駅 歩7分',
#    'ＪＲ山手線/高田馬場駅 歩21分',
#    '新築',
#    '5階建',
#    '4階',
#    '11.75万円',
#    '15000円',
#    '-',
#    '11.75万円',
#    '2K',
#    '25.9m2',
#    'https://suumo.jp/chintai/jnc_000085010317/?bc=100345787994'],),
#  (['賃貸マンション',
#    'ザ・プレミアムキューブG東中野',
#    '東京都中野区東中野５',
#    'ＪＲ中央線/東中野駅 歩7分',
#    '東京メトロ東西線/落合駅 歩7分',
#    'ＪＲ山手線/高田馬場駅 歩21分',
#    '新築',
#    '5階建',
#    '3階',
#    '11.75万円',
#    '15000円',
#    '-',
#    '11.75万円',
#    '2K',
#    '25.9m2',
#    'https://suumo.jp/chintai/jnc_000086598510/?bc=100355137601'],),
#  (['賃貸マンション',
#    'ザ・プレミアムキューブG東中野',
#    '東京都中野区東中野５',
#    'ＪＲ中央線/東中野駅 歩7分',
#    '東京メトロ東西線/落合駅 歩7分',
#    'ＪＲ山手線/高田馬場駅 歩21分',
#    '新築',
#    '5階建',
#    '4階',
#    '11.8万円',
#    '15000円',
#    '-',
#    '11.8万円',
#    '2K',
#    '25.98m2',
#    'https://suumo.jp/chintai/jnc_000085010300/?bc=100345788005'],),
#  (['賃貸マンション',
#    'ザ・プレミアムキューブG東中野',
#    '東京都中野区東中野５',
#    'ＪＲ中央線/東中野駅 歩7分',
#    '東京メトロ東西線/落合駅 歩7分',
#    'ＪＲ山手線/高田馬場駅 歩21分',
#    '新築',
#    '5階建',
#    '4階',
#    '11.8万円',
#    '15000円',
#    '-',
#    '11.8万円',
#    '2K',
#    '25.98m2',
#    'https://suumo.jp/chintai/jnc_000085010299/?bc=100345787999'],),
#  (['賃貸マンション',
#    'ザ・プレミアムキューブG東中野',
#    '東京都中野区東中野５',
#    'ＪＲ中央線/東中野駅 歩7分',
#    '東京メトロ東西線/落合駅 歩7分',
#    'ＪＲ山手線/高田馬場駅 歩21分',
#    '新築',
#    '5階建',
#    '4階',
#    '11.8万円',
#    '15000円',
#    '-',
#    '11.8万円',
#    '2K',
#    '25.98m2',
#    'https://suumo.jp/chintai/jnc_000085010303/?bc=100345787991'],),
#  (['賃貸マンション',
#    'ザ・プレミアムキューブG東中野',
#    '東京都中野区東中野５',
#    'ＪＲ中央線/東中野駅 歩7分',
#    '東京メトロ東西線/落合駅 歩7分',
#    'ＪＲ山手線/高田馬場駅 歩21分',
#    '新築',
#    '5階建',
#    '4階',
#    '11.8万円',
#    '15000円',
#    '-',
#    '11.8万円',
#    '2K',
#    '25.98m2',
#    'https://suumo.jp/chintai/jnc_000085010301/?bc=100355137625'],),
#  (['賃貸マンション',
#    'ザ・プレミアムキューブG東中野',
#    '東京都中野区東中野５',
#    'ＪＲ中央線/東中野駅 歩7分',
#    '東京メトロ東西線/落合駅 歩7分',
#    'ＪＲ山手線/高田馬場駅 歩21分',
#    '新築',
#    '5階建',
#    '4階',
#    '11.8万円',
#    '15000円',
#    '-',
#    '11.8万円',
#    '2K',
#    '25.98m2',
#    'https://suumo.jp/chintai/jnc_000085010302/?bc=100355137641'],),
#  (['賃貸マンション',
#    'ザ・プレミアムキューブG東中野',
#    '東京都中野区東中野５',
#    'ＪＲ中央線/東中野駅 歩7分',
#    '東京メトロ東西線/落合駅 歩7分',
#    'ＪＲ山手線/高田馬場駅 歩21分',
#    '新築',
#    '5階建',
#    '4階',
#    '11.8万円',
#    '15000円',
#    '-',
#    '11.8万円',
#    '2K',
#    '25.9m2',
#    'https://suumo.jp/chintai/jnc_000085010319/?bc=100345787940'],),
#  (['賃貸マンション',
#    'ザ・プレミアムキューブG東中野',
#    '東京都中野区東中野５',
#    'ＪＲ中央線/東中野駅 歩7分',
#    '東京メトロ東西線/落合駅 歩7分',
#    'ＪＲ山手線/高田馬場駅 歩21分',
#    '新築',
#    '5階建',
#    '5階',
#    '11.85万円',
#    '15000円',
#    '-',
#    '11.85万円',
#    '2K',
#    '25.98m2',
#    'https://suumo.jp/chintai/jnc_000086598512/?bc=100355137591'],),
#  (['賃貸マンション',
#    'ザ・プレミアムキューブG東中野',
#    '東京都中野区東中野５',
#    'ＪＲ中央線/東中野駅 歩7分',
#    '東京メトロ東西線/落合駅 歩7分',
#    'ＪＲ山手線/高田馬場駅 歩21分',
#    '新築',
#    '5階建',
#    '5階',
#    '11.85万円',
#    '15000円',
#    '-',
#    '11.85万円',
#    '2K',
#    '25.98m2',
#    'https://suumo.jp/chintai/jnc_000086598511/?bc=100355137546'],),
#  (['賃貸マンション',
#    'ザ・プレミアムキューブG東中野',
#    '東京都中野区東中野５',
#    'ＪＲ中央線/東中野駅 歩7分',
#    '東京メトロ東西線/落合駅 歩7分',
#    'ＪＲ山手線/高田馬場駅 歩21分',
#    '新築',
#    '5階建',
#    '5階',
#    '11.85万円',
#    '15000円',
#    '-',
#    '11.85万円',
#    '2K',
#    '25.98m2',
#    'https://suumo.jp/chintai/jnc_000084778350/?bc=100354541351'],),
#  (['賃貸マンション',
#    'ザ・プレミアムキューブG東中野',
#    '東京都中野区東中野５',
#    'ＪＲ中央線/東中野駅 歩7分',
#    '東京メトロ東西線/落合駅 歩7分',
#    'ＪＲ山手線/高田馬場駅 歩21分',
#    '新築',
#    '5階建',
#    '5階',
#    '11.85万円',
#    '15000円',
#    '-',
#    '11.85万円',
#    '2K',
#    '25.98m2',
#    'https://suumo.jp/chintai/jnc_000086598513/?bc=100354541475'],),
#  (['賃貸マンション',
#    'ハーモニーレジデンス中野本町パークサイド',
#    '東京都中野区本町５',
#    '東京メトロ丸ノ内線/中野新橋駅 歩6分',
#    '東京メトロ丸ノ内線/新中野駅 歩9分',
#    'ＪＲ中央線/中野駅 歩20分',
#    '築3年',
#    '4階建',
#    '1階',
#    '10.95万円',
#    '15000円',
#    '-',
#    '-',
#    '2K',
#    '25.5m2',
#    'https://suumo.jp/chintai/jnc_000075954238/?bc=100351960281'],),
#  (['賃貸マンション',
#    'ハーモニーレジデンス中野本町パークサイド',
#    '東京都中野区本町５',
#    '東京メトロ丸ノ内線/中野新橋駅 歩6分',
#    '東京メトロ丸ノ内線/新中野駅 歩9分',
#    'ＪＲ中央線/中野駅 歩20分',
#    '築3年',
#    '4階建',
#    '1階',
#    '11.1万円',
#    '15000円',
#    '-',
#    '-',
#    '2K',
#    '25.5m2',
#    'https://suumo.jp/chintai/jnc_000086357748/?bc=100353272282'],),
#  (['賃貸マンション',
#    'ハーモニーレジデンス中野本町パークサイド',
#    '東京都中野区本町５',
#    '東京メトロ丸ノ内線/中野新橋駅 歩6分',
#    '東京メトロ丸ノ内線/新中野駅 歩9分',
#    'ＪＲ中央線/中野駅 歩20分',
#    '築3年',
#    '4階建',
#    '4階',
#    '11.5万円',
#    '15000円',
#    '-',
#    '-',
#    '2K',
#    '25.5m2',
#    'https://suumo.jp/chintai/jnc_000086625871/?bc=100354912371'],),
#  (['賃貸マンション',
#    'HF西新宿レジデンスWEST',
#    '東京都新宿区西新宿８',
#    '東京メトロ丸ノ内線/西新宿駅 歩6分',
#    'ＪＲ中央線/大久保駅 歩7分',
#    '西武新宿線/西武新宿駅 歩11分',
#    '築18年',
#    '12階建',
#    '11階',
#    '13.6万円',
#    '12000円',
#    '13.6万円',
#    '-',
#    '11DK',
#    '32.64m2',
#    'https://suumo.jp/chintai/jnc_000086383687/?bc=100352984478'],),
#  (['賃貸マンション',
#    'プラネット',
#    '東京都江戸川区東小岩５',
#    'ＪＲ総武線/小岩駅 歩10分',
#    '京成本線/江戸川駅 歩14分',
#    '京成本線/京成小岩駅 歩18分',
#    '築3年',
#    '2階建',
#    '1階',
#    '6.5万円',
#    '2000円',
#    '6.5万円',
#    '6.5万円',
#    '10K',
#    '25.14m2',
#    'https://suumo.jp/chintai/jnc_000069082397/?bc=100354497924'],),
#  (['賃貸マンション',
#    '日神デュオステージ押上',
#    '東京都墨田区京島２',
#    '東京メトロ半蔵門線/押上駅 歩10分',
#    '京成押上線/京成曳舟駅 歩7分',
#    '東武伊勢崎線/曳舟駅 歩8分',
#    '築15年',
#    '6階建',
#    '1階',
#    '8.5万円',
#    '11000円',
#    '-',
#    '8.5万円',
#    '2K',
#    '30.22m2',
#    'https://suumo.jp/chintai/jnc_000086659395/?bc=100355055164'],),
#  (['賃貸マンション',
#    'ライトテラス上野',
#    '東京都台東区下谷１',
#    'ＪＲ山手線/上野駅 歩9分',
#    '東京メトロ日比谷線/入谷駅 歩3分',
#    'ＪＲ京浜東北線/鶯谷駅 歩7分',
#    '築4年',
#    '13階建',
#    '10階',
#    '12.5万円',
#    '10000円',
#    '-',
#    '-',
#    '2K',
#    '28.03m2',
#    'https://suumo.jp/chintai/jnc_000086625488/?bc=100354744481'],),
#  (['賃貸マンション',
#    'ライトテラス上野',
#    '東京都台東区下谷１',
#    'ＪＲ山手線/上野駅 歩9分',
#    '東京メトロ日比谷線/入谷駅 歩3分',
#    'ＪＲ京浜東北線/鶯谷駅 歩7分',
#    '築4年',
#    '13階建',
#    '7階',
#    '12.2万円',
#    '15000円',
#    '-',
#    '-',
#    '2K',
#    '28.03m2',
#    'https://suumo.jp/chintai/jnc_000086066902/?bc=100350966930'],),
#  (['賃貸マンション',
#    'ライトテラス上野',
#    '東京都台東区下谷１',
#    'ＪＲ山手線/上野駅 歩9分',
#    '東京メトロ日比谷線/入谷駅 歩3分',
#    'ＪＲ京浜東北線/鶯谷駅 歩7分',
#    '築4年',
#    '13階建',
#    '10階',
#    '12.5万円',
#    '15000円',
#    '-',
#    '-',
#    '2K',
#    '28.03m2',
#    'https://suumo.jp/chintai/jnc_000086059601/?bc=100342827976'],),
#  (['賃貸マンション',
#    'ライトテラス上野',
#    '東京都台東区下谷１',
#    'ＪＲ山手線/上野駅 歩9分',
#    '東京メトロ日比谷線/入谷駅 歩3分',
#    'ＪＲ京浜東北線/鶯谷駅 歩7分',
#    '築4年',
#    '13階建',
#    '10階',
#    '12.6万円',
#    '15000円',
#    '12.6万円',
#    '12.6万円',
#    '2K',
#    '28.03m2',
#    'https://suumo.jp/chintai/jnc_000084811629/?bc=100343941853'],),
#  (['賃貸マンション',
#    'アヴァンティーク銀座一丁目',
#    '東京都中央区銀座１',
#    '東京メトロ銀座線/銀座駅 歩8分',
#    '都営浅草線/宝町駅 歩4分',
#    '東京メトロ有楽町線/銀座一丁目駅 歩4分',
#    '築23年',
#    '13階建',
#    '4階',
#    '15.6万円',
#    '14000円',
#    '15.6万円',
#    '15.6万円',
#    '2K',
#    '40.81m2',
#    'https://suumo.jp/chintai/jnc_000068734314/?bc=100347639296'],),
#  (['賃貸マンション',
#    '東京メトロ日比谷線 入谷駅 13階建 築4年',
#    '東京都台東区下谷１',
#    '東京メトロ日比谷線/入谷駅 歩3分',
#    'ＪＲ山手線/上野駅 歩9分',
#    'ＪＲ京浜東北線/鶯谷駅 歩8分',
#    '築4年',
#    '13階建',
#    '7階',
#    '12.2万円',
#    '15000円',
#    '-',
#    '-',
#    '2K',
#    '28.03m2',
#    'https://suumo.jp/chintai/jnc_000086082902/?bc=100352834755'],),
#  (['賃貸マンション',
#    '東京メトロ日比谷線 入谷駅 13階建 築4年',
#    '東京都台東区下谷１',
#    '東京メトロ日比谷線/入谷駅 歩3分',
#    'ＪＲ山手線/上野駅 歩9分',
#    'ＪＲ京浜東北線/鶯谷駅 歩8分',
#    '築4年',
#    '13階建',
#    '10階',
#    '12.5万円',
#    '15000円',
#    '-',
#    '-',
#    '2K',
#    '28.03m2',
#    'https://suumo.jp/chintai/jnc_000086072679/?bc=100334371085'],),
#  (['賃貸アパート',
#    'ＪＲ総武線 亀戸駅 3階建 築15年',
#    '東京都江東区亀戸５',
#    'ＪＲ総武線/亀戸駅 歩5分',
#    '東武亀戸線/亀戸水神駅 歩9分',
#    '都営新宿線/西大島駅 歩18分',
#    '築15年',
#    '3階建',
#    '1階',
#    '8.6万円',
#    '-',
#    '8.6万円',
#    '8.6万円',
#    '2K',
#    '32.74m2',
#    'https://suumo.jp/chintai/jnc_000086708837/?bc=100355432720'],),
#  (['賃貸マンション',
#    'ライオンズマンション日暮里駅前',
#    '東京都荒川区東日暮里５',
#    'ＪＲ山手線/日暮里駅 歩2分',
#    'ＪＲ常磐線/三河島駅 歩14分',
#    '日暮里・舎人ライナー/西日暮里駅 歩10分',
#    '築41年',
#    '11階建',
#    '4階',
#    '16.8万円',
#    '-',
#    '16.8万円',
#    '16.8万円',
#    '3DK',
#    '55.39m2',
#    'https://suumo.jp/chintai/jnc_000086630636/?bc=100355040583'],),
#  (['賃貸マンション',
#    'ライオンズマンション日暮里駅前',
#    '東京都荒川区東日暮里５',
#    'ＪＲ山手線/日暮里駅 歩2分',
#    'ＪＲ常磐線/三河島駅 歩14分',
#    '日暮里・舎人ライナー/西日暮里駅 歩10分',
#    '築41年',
#    '11階建',
#    '6階',
#    '17.5万円',
#    '-',
#    '17.5万円',
#    '17.5万円',
#    '3DK',
#    '55.39m2',
#    'https://suumo.jp/chintai/jnc_000053311010/?bc=100335173564'],),
#  (['賃貸マンション',
#    'ライオンズマンション日暮里駅前',
#    '東京都荒川区東日暮里５',
#    'ＪＲ山手線/日暮里駅 歩2分',
#    'ＪＲ常磐線/三河島駅 歩14分',
#    '日暮里・舎人ライナー/西日暮里駅 歩10分',
#    '築41年',
#    '11階建',
#    '7階',
#    '18万円',
#    '10000円',
#    '18万円',
#    '-',
#    '2LDK',
#    '50.37m2',
#    'https://suumo.jp/chintai/jnc_000084040010/?bc=100351340293'],),
#  (['賃貸一戸建て',
#    '雨宮貸家',
#    '東京都江戸川区北小岩２',
#    'ＪＲ総武線/小岩駅 歩10分',
#    '京成本線/京成小岩駅 歩9分',
#    '京成本線/江戸川駅 歩10分',
#    '築31年',
#    '3階建',
#    '2-3階',
#    '11万円',
#    '-',
#    '11万円',
#    '11万円',
#    '3DK',
#    '70m2',
#    'https://suumo.jp/chintai/jnc_000086768491/?bc=100355661006'],),
#  (['賃貸マンション',
#    'ガーラ練馬グランドステージ',
#    '東京都練馬区豊玉中３',
#    '西武池袋線/練馬駅 歩7分',
#    '都営大江戸線/豊島園駅 歩17分',
#    '西武池袋線/桜台駅 歩18分',
#    '築5年',
#    '地下1地上4階建',
#    '2階',
#    '8.9万円',
#    '10000円',
#    '8.9万円',
#    '17.8万円',
#    '2K',
#    '25.96m2',
#    'https://suumo.jp/chintai/jnc_000045914543/?bc=100354863142'],),
#  (['賃貸マンション',
#    'ガーラ練馬グランドステージ',
#    '東京都練馬区豊玉中３',
#    '西武池袋線/練馬駅 歩7分',
#    '都営大江戸線/豊島園駅 歩17分',
#    '西武池袋線/桜台駅 歩18分',
#    '築5年',
#    '地下1地上4階建',
#    '2階',
#    '8.95万円',
#    '10000円',
#    '8.95万円',
#    '17.9万円',
#    '2K',
#    '25.81m2',
#    'https://suumo.jp/chintai/jnc_000072879368/?bc=100353877871'],),
#  (['賃貸マンション',
#    'ガーラ練馬グランドステージ',
#    '東京都練馬区豊玉中３',
#    '西武池袋線/練馬駅 歩7分',
#    '都営大江戸線/豊島園駅 歩17分',
#    '西武池袋線/桜台駅 歩18分',
#    '築5年',
#    '地下1地上4階建',
#    '2階',
#    '8.95万円',
#    '10000円',
#    '8.95万円',
#    '17.9万円',
#    '2K',
#    '25.81m2',
#    'https://suumo.jp/chintai/jnc_000058392381/?bc=100355523384'],),
#  (['賃貸マンション',
#    'ガーラ練馬グランドステージ',
#    '東京都練馬区豊玉中３',
#    '西武池袋線/練馬駅 歩7分',
#    '都営大江戸線/豊島園駅 歩17分',
#    '西武池袋線/桜台駅 歩18分',
#    '築5年',
#    '地下1地上4階建',
#    '3階',
#    '9.3万円',
#    '10000円',
#    '9.3万円',
#    '18.6万円',
#    '2K',
#    '25.96m2',
#    'https://suumo.jp/chintai/jnc_000086380147/?bc=100353059002'],),
#  (['賃貸マンション',
#    'ガーラ練馬グランドステージ',
#    '東京都練馬区豊玉中３',
#    '西武池袋線/練馬駅 歩7分',
#    '都営大江戸線/豊島園駅 歩17分',
#    '西武池袋線/桜台駅 歩18分',
#    '築5年',
#    '地下1地上4階建',
#    '4階',
#    '9.7万円',
#    '10000円',
#    '9.7万円',
#    '19.4万円',
#    '2K',
#    '25.92m2',
#    'https://suumo.jp/chintai/jnc_000056611298/?bc=100354561485'],),
#  (['賃貸マンション',
#    'ガーラ練馬グランドステージ',
#    '東京都練馬区豊玉中３',
#    '西武池袋線/練馬駅 歩7分',
#    '都営大江戸線/豊島園駅 歩17分',
#    '西武池袋線/桜台駅 歩18分',
#    '築5年',
#    '地下1地上4階建',
#    '3階',
#    '9.7万円',
#    '10000円',
#    '9.7万円',
#    '19.4万円',
#    '2K',
#    '25.92m2',
#    'https://suumo.jp/chintai/jnc_000086272090/?bc=100353079157'],),
#  (['賃貸マンション',
#    'ガーラ練馬グランドステージ',
#    '東京都練馬区豊玉中３',
#    '西武池袋線/練馬駅 歩7分',
#    '都営大江戸線/豊島園駅 歩17分',
#    '西武池袋線/桜台駅 歩18分',
#    '築5年',
#    '地下1地上4階建',
#    '4階',
#    '9.7万円',
#    '10000円',
#    '9.7万円',
#    '19.4万円',
#    '2K',
#    '25.92m2',
#    'https://suumo.jp/chintai/jnc_000086529693/?bc=100354036547'],),
#  (['賃貸マンション',
#    'ガーラ練馬グランドステージ',
#    '東京都練馬区豊玉中３',
#    '西武池袋線/練馬駅 歩7分',
#    '都営大江戸線/豊島園駅 歩17分',
#    '西武池袋線/桜台駅 歩18分',
#    '築5年',
#    '地下1地上4階建',
#    '4階',
#    '9.7万円',
#    '10000円',
#    '9.7万円',
#    '19.4万円',
#    '2K',
#    '25.92m2',
#    'https://suumo.jp/chintai/jnc_000067010384/?bc=100354562567'],),
#  (['賃貸マンション',
#    'ガーラ・ヴィスタ練馬',
#    '東京都練馬区豊玉北４',
#    '西武池袋線/練馬駅 歩7分',
#    '都営大江戸線/練馬駅 歩6分',
#    '西武池袋線/桜台駅 歩7分',
#    '築8年',
#    '5階建',
#    '2階',
#    '12.3万円',
#    '12000円',
#    '12.3万円',
#    '24.6万円',
#    '2K',
#    '36.09m2',
#    'https://suumo.jp/chintai/jnc_000086717626/?bc=100353885214'],),
#  (['賃貸マンション',
#    'ガーラ・ヴィスタ練馬',
#    '東京都練馬区豊玉北４',
#    '西武池袋線/練馬駅 歩7分',
#    '都営大江戸線/練馬駅 歩6分',
#    '西武池袋線/桜台駅 歩7分',
#    '築8年',
#    '5階建',
#    '2階',
#    '12.6万円',
#    '12000円',
#    '12.6万円',
#    '25.2万円',
#    '2K',
#    '36.09m2',
#    'https://suumo.jp/chintai/jnc_000086490316/?bc=100353901110'],),
#  (['賃貸マンション',
#    'ガーラ・ヴィスタ練馬',
#    '東京都練馬区豊玉北４',
#    '西武池袋線/練馬駅 歩7分',
#    '都営大江戸線/練馬駅 歩6分',
#    '西武池袋線/桜台駅 歩7分',
#    '築8年',
#    '5階建',
#    '2階',
#    '12.6万円',
#    '12000円',
#    '12.6万円',
#    '25.2万円',
#    '2K',
#    '36.09m2',
#    'https://suumo.jp/chintai/jnc_000086490315/?bc=100354015810'],),
#  (['賃貸マンション',
#    'ガーラ・ヴィスタ練馬',
#    '東京都練馬区豊玉北４',
#    '西武池袋線/練馬駅 歩7分',
#    '都営大江戸線/練馬駅 歩6分',
#    '西武池袋線/桜台駅 歩7分',
#    '築8年',
#    '5階建',
#    '2階',
#    '12.6万円',
#    '12000円',
#    '12.6万円',
#    '25.2万円',
#    '2K',
#    '36.09m2',
#    'https://suumo.jp/chintai/jnc_000086510410/?bc=100353905639'],),
#  (['賃貸マンション',
#    '前畑ビル',
#    '東京都千代田区神田和泉町',
#    '東京メトロ日比谷線/秋葉原駅 歩4分',
#    '東京メトロ銀座線/末広町駅 歩10分',
#    '都営新宿線/岩本町駅 歩8分',
#    '築48年',
#    '3階建',
#    '3階',
#    '15万円',
#    '-',
#    '15万円',
#    '15万円',
#    '3DK',
#    '53.64m2',
#    'https://suumo.jp/chintai/jnc_000086699512/?bc=100355226012'],),
#  (['賃貸マンション',
#    '都営大江戸線 練馬駅 7階建 築5年',
#    '東京都練馬区豊玉北３',
#    '都営大江戸線/練馬駅 歩10分',
#    '西武池袋線/桜台駅 歩5分',
#    '西武有楽町線/新桜台駅 歩9分',
#    '築5年',
#    '7階建',
#    '2階',
#    '8.7万円',
#    '9000円',
#    '8.7万円',
#    '17.4万円',
#    '2K',
#    '25.8m2',
#    'https://suumo.jp/chintai/jnc_000049727321/?bc=100354987726'],),
#  (['賃貸マンション',
#    '都営大江戸線 練馬駅 7階建 築5年',
#    '東京都練馬区豊玉北３',
#    '都営大江戸線/練馬駅 歩10分',
#    '西武池袋線/桜台駅 歩5分',
#    '西武有楽町線/新桜台駅 歩9分',
#    '築5年',
#    '7階建',
#    '2階',
#    '8.7万円',
#    '9000円',
#    '8.7万円',
#    '17.4万円',
#    '2K',
#    '25.8m2',
#    'https://suumo.jp/chintai/jnc_000049745654/?bc=100355217814'],),
#  (['賃貸マンション',
#    '都営大江戸線 練馬駅 7階建 築5年',
#    '東京都練馬区豊玉北３',
#    '都営大江戸線/練馬駅 歩10分',
#    '西武池袋線/桜台駅 歩5分',
#    '西武有楽町線/新桜台駅 歩9分',
#    '築5年',
#    '7階建',
#    '3階',
#    '8.75万円',
#    '9000円',
#    '8.75万円',
#    '17.5万円',
#    '2K',
#    '25.8m2',
#    'https://suumo.jp/chintai/jnc_000050711352/?bc=100353149834'],),
#  (['賃貸マンション',
#    '都営大江戸線 練馬駅 7階建 築5年',
#    '東京都練馬区豊玉北３',
#    '都営大江戸線/練馬駅 歩10分',
#    '西武池袋線/桜台駅 歩5分',
#    '西武有楽町線/新桜台駅 歩9分',
#    '築5年',
#    '7階建',
#    '3階',
#    '8.75万円',
#    '9000円',
#    '8.75万円',
#    '17.5万円',
#    '2K',
#    '25.8m2',
#    'https://suumo.jp/chintai/jnc_000077657411/?bc=100353183592'],),
#  (['賃貸マンション',
#    '都営大江戸線 練馬駅 7階建 築5年',
#    '東京都練馬区豊玉北３',
#    '都営大江戸線/練馬駅 歩10分',
#    '西武池袋線/桜台駅 歩5分',
#    '西武有楽町線/新桜台駅 歩9分',
#    '築5年',
#    '7階建',
#    '3階',
#    '9.7万円',
#    '10000円',
#    '9.7万円',
#    '19.4万円',
#    '2K',
#    '28.41m2',
#    'https://suumo.jp/chintai/jnc_000070703445/?bc=100354987727'],),
#  (['賃貸マンション',
#    '東武東上線 下板橋駅 7階建 新築',
#    '東京都豊島区池袋本町２',
#    '東武東上線/下板橋駅 歩8分',
#    '東武東上線/北池袋駅 歩9分',
#    'ＪＲ埼京線/板橋駅 歩15分',
#    '新築',
#    '7階建',
#    '1階',
#    '11.55万円',
#    '10000円',
#    '-',
#    '-',
#    '2K',
#    '25.95m2',
#    'https://suumo.jp/chintai/jnc_000084613525/?bc=100343959723'],),
#  (['賃貸マンション',
#    '東武東上線 下板橋駅 7階建 新築',
#    '東京都豊島区池袋本町２',
#    '東武東上線/下板橋駅 歩8分',
#    '東武東上線/北池袋駅 歩9分',
#    'ＪＲ埼京線/板橋駅 歩15分',
#    '新築',
#    '7階建',
#    '1階',
#    '11.55万円',
#    '10000円',
#    '-',
#    '-',
#    '2K',
#    '25.95m2',
#    'https://suumo.jp/chintai/jnc_000084663500/?bc=100342865177'],),
#  (['賃貸マンション',
#    '東武東上線 下板橋駅 7階建 新築',
#    '東京都豊島区池袋本町２',
#    '東武東上線/下板橋駅 歩8分',
#    '東武東上線/北池袋駅 歩9分',
#    'ＪＲ埼京線/板橋駅 歩15分',
#    '新築',
#    '7階建',
#    '1階',
#    '11.55万円',
#    '10000円',
#    '-',
#    '-',
#    '2K',
#    '25.95m2',
#    'https://suumo.jp/chintai/jnc_000084619708/?bc=100342865144'],),
#  (['賃貸マンション',
#    '東武東上線 下板橋駅 7階建 新築',
#    '東京都豊島区池袋本町２',
#    '東武東上線/下板橋駅 歩8分',
#    '東武東上線/北池袋駅 歩9分',
#    'ＪＲ埼京線/板橋駅 歩15分',
#    '新築',
#    '7階建',
#    '2階',
#    '11.65万円',
#    '10000円',
#    '-',
#    '-',
#    '2K',
#    '25.95m2',
#    'https://suumo.jp/chintai/jnc_000084648468/?bc=100342098843'],),
#  (['賃貸マンション',
#    '東武東上線 下板橋駅 7階建 新築',
#    '東京都豊島区池袋本町２',
#    '東武東上線/下板橋駅 歩8分',
#    '東武東上線/北池袋駅 歩9分',
#    'ＪＲ埼京線/板橋駅 歩15分',
#    '新築',
#    '7階建',
#    '2階',
#    '11.65万円',
#    '10000円',
#    '-',
#    '-',
#    '2K',
#    '25.95m2',
#    'https://suumo.jp/chintai/jnc_000084658664/?bc=100342537750'],),
#  (['賃貸マンション',
#    '東武東上線 下板橋駅 7階建 新築',
#    '東京都豊島区池袋本町２',
#    '東武東上線/下板橋駅 歩8分',
#    '東武東上線/北池袋駅 歩9分',
#    'ＪＲ埼京線/板橋駅 歩15分',
#    '新築',
#    '7階建',
#    '2階',
#    '11.7万円',
#    '10000円',
#    '-',
#    '-',
#    '2K',
#    '25.95m2',
#    'https://suumo.jp/chintai/jnc_000084613528/?bc=100355564505'],),
#  (['賃貸マンション',
#    '東武東上線 下板橋駅 7階建 新築',
#    '東京都豊島区池袋本町２',
#    '東武東上線/下板橋駅 歩8分',
#    '東武東上線/北池袋駅 歩9分',
#    'ＪＲ埼京線/板橋駅 歩15分',
#    '新築',
#    '7階建',
#    '3階',
#    '11.7万円',
#    '10000円',
#    '-',
#    '-',
#    '2K',
#    '25.95m2',
#    'https://suumo.jp/chintai/jnc_000084663505/?bc=100343488289'],),
#  (['賃貸マンション',
#    '東武東上線 下板橋駅 7階建 新築',
#    '東京都豊島区池袋本町２',
#    '東武東上線/下板橋駅 歩8分',
#    '東武東上線/北池袋駅 歩9分',
#    'ＪＲ埼京線/板橋駅 歩15分',
#    '新築',
#    '7階建',
#    '3階',
#    '11.7万円',
#    '10000円',
#    '-',
#    '-',
#    '2K',
#    '25.95m2',
#    'https://suumo.jp/chintai/jnc_000084667704/?bc=100342098868'],),
#  (['賃貸マンション',
#    '東武東上線 下板橋駅 7階建 新築',
#    '東京都豊島区池袋本町２',
#    '東武東上線/下板橋駅 歩8分',
#    '東武東上線/北池袋駅 歩9分',
#    'ＪＲ埼京線/板橋駅 歩15分',
#    '新築',
#    '7階建',
#    '2階',
#    '11.7万円',
#    '10000円',
#    '-',
#    '-',
#    '2K',
#    '25.95m2',
#    'https://suumo.jp/chintai/jnc_000084613527/?bc=100342865240'],),
#  (['賃貸マンション',
#    '東武東上線 下板橋駅 7階建 新築',
#    '東京都豊島区池袋本町２',
#    '東武東上線/下板橋駅 歩8分',
#    '東武東上線/北池袋駅 歩9分',
#    'ＪＲ埼京線/板橋駅 歩15分',
#    '新築',
#    '7階建',
#    '4階',
#    '11.75万円',
#    '10000円',
#    '-',
#    '-',
#    '2K',
#    '25.95m2',
#    'https://suumo.jp/chintai/jnc_000084667705/?bc=100342098826'],),
#  (['賃貸マンション',
#    '東武東上線 下板橋駅 7階建 新築',
#    '東京都豊島区池袋本町２',
#    '東武東上線/下板橋駅 歩8分',
#    '東武東上線/北池袋駅 歩9分',
#    'ＪＲ埼京線/板橋駅 歩15分',
#    '新築',
#    '7階建',
#    '3階',
#    '11.75万円',
#    '10000円',
#    '-',
#    '-',
#    '2K',
#    '25.95m2',
#    'https://suumo.jp/chintai/jnc_000084663503/?bc=100342865140'],),
#  (['賃貸マンション',
#    '東武東上線 下板橋駅 7階建 新築',
#    '東京都豊島区池袋本町２',
#    '東武東上線/下板橋駅 歩8分',
#    '東武東上線/北池袋駅 歩9分',
#    'ＪＲ埼京線/板橋駅 歩15分',
#    '新築',
#    '7階建',
#    '3階',
#    '11.75万円',
#    '10000円',
#    '-',
#    '-',
#    '2K',
#    '25.95m2',
#    'https://suumo.jp/chintai/jnc_000084613530/?bc=100342865139'],),
#  (['賃貸マンション',
#    '東武東上線 下板橋駅 7階建 新築',
#    '東京都豊島区池袋本町２',
#    '東武東上線/下板橋駅 歩8分',
#    '東武東上線/北池袋駅 歩9分',
#    'ＪＲ埼京線/板橋駅 歩15分',
#    '新築',
#    '7階建',
#    '3階',
#    '11.75万円',
#    '10000円',
#    '-',
#    '-',
#    '2K',
#    '25.95m2',
#    'https://suumo.jp/chintai/jnc_000084613529/?bc=100342864765'],),
#  (['賃貸マンション',
#    '東武東上線 下板橋駅 7階建 新築',
#    '東京都豊島区池袋本町２',
#    '東武東上線/下板橋駅 歩8分',
#    '東武東上線/北池袋駅 歩9分',
#    'ＪＲ埼京線/板橋駅 歩15分',
#    '新築',
#    '7階建',
#    '4階',
#    '11.75万円',
#    '10000円',
#    '-',
#    '-',
#    '2K',
#    '25.95m2',
#    'https://suumo.jp/chintai/jnc_000084663508/?bc=100342098856'],),
#  (['賃貸マンション',
#    '東武東上線 下板橋駅 7階建 新築',
#    '東京都豊島区池袋本町２',
#    '東武東上線/下板橋駅 歩8分',
#    '東武東上線/北池袋駅 歩9分',
#    'ＪＲ埼京線/板橋駅 歩15分',
#    '新築',
#    '7階建',
#    '4階',
#    '11.8万円',
#    '10000円',
#    '-',
#    '-',
#    '2K',
#    '25.95m2',
#    'https://suumo.jp/chintai/jnc_000084613532/?bc=100355527858'],),
#  (['賃貸マンション',
#    '東武東上線 下板橋駅 7階建 新築',
#    '東京都豊島区池袋本町２',
#    '東武東上線/下板橋駅 歩8分',
#    '東武東上線/北池袋駅 歩9分',
#    'ＪＲ埼京線/板橋駅 歩15分',
#    '新築',
#    '7階建',
#    '3階',
#    '11.8万円',
#    '10000円',
#    '-',
#    '-',
#    '2K',
#    '25.95m2',
#    'https://suumo.jp/chintai/jnc_000086747548/?bc=100355527881'],),
#  (['賃貸マンション',
#    '東武東上線 下板橋駅 7階建 新築',
#    '東京都豊島区池袋本町２',
#    '東武東上線/下板橋駅 歩8分',
#    '東武東上線/北池袋駅 歩9分',
#    'ＪＲ埼京線/板橋駅 歩15分',
#    '新築',
#    '7階建',
#    '4階',
#    '11.8万円',
#    '10000円',
#    '-',
#    '-',
#    '2K',
#    '25.95m2',
#    'https://suumo.jp/chintai/jnc_000084663507/?bc=100348529476'],),
#  (['賃貸マンション',
#    '東武東上線 下板橋駅 7階建 新築',
#    '東京都豊島区池袋本町２',
#    '東武東上線/下板橋駅 歩8分',
#    '東武東上線/北池袋駅 歩9分',
#    'ＪＲ埼京線/板橋駅 歩15分',
#    '新築',
#    '7階建',
#    '4階',
#    '11.8万円',
#    '10000円',
#    '-',
#    '-',
#    '2K',
#    '25.95m2',
#    'https://suumo.jp/chintai/jnc_000084613531/?bc=100347768790'],),
#  (['賃貸マンション',
#    '東武東上線 下板橋駅 7階建 新築',
#    '東京都豊島区池袋本町２',
#    '東武東上線/下板橋駅 歩8分',
#    '東武東上線/北池袋駅 歩9分',
#    'ＪＲ埼京線/板橋駅 歩15分',
#    '新築',
#    '7階建',
#    '5階',
#    '11.8万円',
#    '10000円',
#    '-',
#    '-',
#    '2K',
#    '25.95m2',
#    'https://suumo.jp/chintai/jnc_000084663510/?bc=100350764920'],),
#  (['賃貸マンション',
#    '東武東上線 下板橋駅 7階建 新築',
#    '東京都豊島区池袋本町２',
#    '東武東上線/下板橋駅 歩8分',
#    '東武東上線/北池袋駅 歩9分',
#    'ＪＲ埼京線/板橋駅 歩15分',
#    '新築',
#    '7階建',
#    '6階',
#    '11.9万円',
#    '10000円',
#    '-',
#    '-',
#    '2K',
#    '25.95m2',
#    'https://suumo.jp/chintai/jnc_000084613536/?bc=100355217817'],),
#  (['賃貸マンション',
#    'ジェノヴィア池袋本町',
#    '東京都豊島区池袋本町２',
#    '東武東上線/下板橋駅 歩8分',
#    '東武東上線/北池袋駅 歩9分',
#    'ＪＲ埼京線/板橋駅 歩15分',
#    '新築',
#    '7階建',
#    '1階',
#    '11.55万円',
#    '10000円',
#    '-',
#    '-',
#    '2K',
#    '25.95m2',
#    'https://suumo.jp/chintai/jnc_000084608280/?bc=100343934780'],),
#  (['賃貸マンション',
#    'ジェノヴィア池袋本町',
#    '東京都豊島区池袋本町２',
#    '東武東上線/下板橋駅 歩8分',
#    '東武東上線/北池袋駅 歩9分',
#    'ＪＲ埼京線/板橋駅 歩15分',
#    '新築',
#    '7階建',
#    '1階',
#    '11.55万円',
#    '10000円',
#    '-',
#    '-',
#    '2K',
#    '25.95m2',
#    'https://suumo.jp/chintai/jnc_000084613509/?bc=100342823614'],),
#  (['賃貸マンション',
#    'ジェノヴィア池袋本町',
#    '東京都豊島区池袋本町２',
#    '東武東上線/下板橋駅 歩8分',
#    '東武東上線/北池袋駅 歩9分',
#    'ＪＲ埼京線/板橋駅 歩15分',
#    '新築',
#    '7階建',
#    '1階',
#    '11.55万円',
#    '10000円',
#    '-',
#    '-',
#    '2K',
#    '25.95m2',
#    'https://suumo.jp/chintai/jnc_000084619685/?bc=100342864750'],),
#  (['賃貸マンション',
#    'ジェノヴィア池袋本町',
#    '東京都豊島区池袋本町２',
#    '東武東上線/下板橋駅 歩8分',
#    '東武東上線/北池袋駅 歩9分',
#    'ＪＲ埼京線/板橋駅 歩15分',
#    '新築',
#    '7階建',
#    '1階',
#    '11.55万円',
#    '10000円',
#    '-',
#    '-',
#    '2K',
#    '25.95m2',
#    'https://suumo.jp/chintai/jnc_000084608279/?bc=100342339364'],),
#  (['賃貸マンション',
#    'ジェノヴィア池袋本町',
#    '東京都豊島区池袋本町２',
#    '東武東上線/下板橋駅 歩8分',
#    '東武東上線/北池袋駅 歩9分',
#    'ＪＲ埼京線/板橋駅 歩15分',
#    '新築',
#    '7階建',
#    '2階',
#    '11.65万円',
#    '10000円',
#    '-',
#    '-',
#    '2K',
#    '25.95m2',
#    'https://suumo.jp/chintai/jnc_000084608281/?bc=100346692058'],),
#  (['賃貸マンション',
#    'ジェノヴィア池袋本町',
#    '東京都豊島区池袋本町２',
#    '東武東上線/下板橋駅 歩8分',
#    '東武東上線/北池袋駅 歩9分',
#    'ＪＲ埼京線/板橋駅 歩15分',
#    '新築',
#    '7階建',
#    '2階',
#    '11.65万円',
#    '10000円',
#    '-',
#    '-',
#    '2K',
#    '25.95m2',
#    'https://suumo.jp/chintai/jnc_000084613515/?bc=100342489664'],),
#  (['賃貸マンション',
#    'ジェノヴィア池袋本町',
#    '東京都豊島区池袋本町２',
#    '東武東上線/下板橋駅 歩8分',
#    '東武東上線/北池袋駅 歩9分',
#    'ＪＲ埼京線/板橋駅 歩15分',
#    '新築',
#    '7階建',
#    '2階',
#    '11.7万円',
#    '10000円',
#    '-',
#    '-',
#    '2K',
#    '25.95m2',
#    'https://suumo.jp/chintai/jnc_000084613512/?bc=100347263806'],),
#  (['賃貸マンション',
#    'ジェノヴィア池袋本町',
#    '東京都豊島区池袋本町２',
#    '東武東上線/下板橋駅 歩8分',
#    '東武東上線/北池袋駅 歩9分',
#    'ＪＲ埼京線/板橋駅 歩15分',
#    '新築',
#    '7階建',
#    '4階',
#    '11.7万円',
#    '10000円',
#    '-',
#    '-',
#    '2K',
#    '25.95m2',
#    'https://suumo.jp/chintai/jnc_000085459633/?bc=100347036614'],),
#  (['賃貸マンション',
#    'ジェノヴィア池袋本町',
#    '東京都豊島区池袋本町２',
#    '東武東上線/下板橋駅 歩8分',
#    '東武東上線/北池袋駅 歩9分',
#    'ＪＲ埼京線/板橋駅 歩15分',
#    '新築',
#    '7階建',
#    '3階',
#    '11.7万円',
#    '10000円',
#    '-',
#    '-',
#    '2K',
#    '25.95m2',
#    'https://suumo.jp/chintai/jnc_000084613518/?bc=100343170301'],),
#  (['賃貸マンション',
#    'ジェノヴィア池袋本町',
#    '東京都豊島区池袋本町２',
#    '東武東上線/下板橋駅 歩8分',
#    '東武東上線/北池袋駅 歩9分',
#    'ＪＲ埼京線/板橋駅 歩15分',
#    '新築',
#    '7階建',
#    '3階',
#    '11.7万円',
#    '10000円',
#    '-',
#    '-',
#    '2K',
#    '25.95m2',
#    'https://suumo.jp/chintai/jnc_000084625779/?bc=100342810399'],),
#  (['賃貸マンション',
#    'ジェノヴィア池袋本町',
#    '東京都豊島区池袋本町２',
#    '東武東上線/下板橋駅 歩8分',
#    '東武東上線/北池袋駅 歩9分',
#    'ＪＲ埼京線/板橋駅 歩15分',
#    '新築',
#    '7階建',
#    '2階',
#    '11.7万円',
#    '10000円',
#    '-',
#    '-',
#    '2K',
#    '25.95m2',
#    'https://suumo.jp/chintai/jnc_000084613510/?bc=100341933569'],),
#  (['賃貸マンション',
#    'ジェノヴィア池袋本町',
#    '東京都豊島区池袋本町２',
#    '東武東上線/下板橋駅 歩8分',
#    '東武東上線/北池袋駅 歩9分',
#    'ＪＲ埼京線/板橋駅 歩15分',
#    '新築',
#    '7階建',
#    '3階',
#    '11.75万円',
#    '10000円',
#    '-',
#    '-',
#    '2K',
#    '25.95m2',
#    'https://suumo.jp/chintai/jnc_000084613517/?bc=100352619200'],),
#  (['賃貸マンション',
#    'ジェノヴィア池袋本町',
#    '東京都豊島区池袋本町２',
#    '東武東上線/下板橋駅 歩8分',
#    '東武東上線/北池袋駅 歩9分',
#    'ＪＲ埼京線/板橋駅 歩15分',
#    '新築',
#    '7階建',
#    '4階',
#    '11.75万円',
#    '10000円',
#    '-',
#    '-',
#    '2K',
#    '25.95m2',
#    'https://suumo.jp/chintai/jnc_000084613520/?bc=100342810473'],),
#  (['賃貸マンション',
#    'ジェノヴィア池袋本町',
#    '東京都豊島区池袋本町２',
#    '東武東上線/下板橋駅 歩8分',
#    '東武東上線/北池袋駅 歩9分',
#    'ＪＲ埼京線/板橋駅 歩15分',
#    '新築',
#    '7階建',
#    '4階',
#    '11.75万円',
#    '10000円',
#    '-',
#    '-',
#    '2K',
#    '25.95m2',
#    'https://suumo.jp/chintai/jnc_000084619706/?bc=100342028459'],),
#  (['賃貸マンション',
#    'ジェノヴィア池袋本町',
#    '東京都豊島区池袋本町２',
#    '東武東上線/下板橋駅 歩8分',
#    '東武東上線/北池袋駅 歩9分',
#    'ＪＲ埼京線/板橋駅 歩15分',
#    '新築',
#    '7階建',
#    '3階',
#    '11.75万円',
#    '10000円',
#    '-',
#    '-',
#    '2K',
#    '25.95m2',
#    'https://suumo.jp/chintai/jnc_000084613516/?bc=100341999604'],),
#  (['賃貸マンション',
#    'ジェノヴィア池袋本町',
#    '東京都豊島区池袋本町２',
#    '東武東上線/下板橋駅 歩8分',
#    '東武東上線/北池袋駅 歩9分',
#    'ＪＲ埼京線/板橋駅 歩15分',
#    '新築',
#    '7階建',
#    '3階',
#    '11.75万円',
#    '10000円',
#    '-',
#    '-',
#    '2K',
#    '25.95m2',
# ...
#    'メゾン・ド・ヴィオレ',
#    '東京都大田区東矢口３',
#    '東急池上線/蓮沼駅 歩6分',
#    '東急多摩川線/矢口渡駅 歩9分',
#    '東急多摩川線/蒲田駅 歩10分',
#    '築29年',
#    '4階建',
#    '4階',
#    '12万円',
#    '5000円',
#    '12万円',
#    '12万円',
#    '2DK',
#    '40.46m2',
#    'https://suumo.jp/chintai/jnc_000086423628/?bc=100353322313'],),
#  (['賃貸マンション',
#    'ＪＲ京浜東北線 蒲田駅 4階建 築29年',
#    '東京都大田区東矢口３',
#    'ＪＲ京浜東北線/蒲田駅 歩10分',
#    '東急池上線/蓮沼駅 歩4分',
#    '東急多摩川線/矢口渡駅 歩8分',
#    '築29年',
#    '4階建',
#    '4階',
#    '12万円',
#    '5000円',
#    '12万円',
#    '12万円',
#    '2DK',
#    '40.46m2',
#    'https://suumo.jp/chintai/jnc_000086758304/?bc=100355602629'],),
#  (['賃貸マンション',
#    'ＪＲ京浜東北線 赤羽駅 4階建 築31年',
#    '東京都北区赤羽１',
#    'ＪＲ京浜東北線/赤羽駅 歩7分',
#    '東京メトロ南北線/赤羽岩淵駅 歩3分',
#    '東京メトロ南北線/志茂駅 歩17分',
#    '築31年',
#    '4階建',
#    '2階',
#    '11.5万円',
#    '-',
#    '11.5万円',
#    '-',
#    '3K',
#    '46.92m2',
#    'https://suumo.jp/chintai/jnc_000061088020/?bc=100336074082'],),
#  (['賃貸マンション',
#    '要町ガーデンハイツ',
#    '東京都豊島区要町１',
#    '東京メトロ副都心線/要町駅 歩5分',
#    '東京メトロ有楽町線/要町駅 歩5分',
#    '西武池袋線/椎名町駅 歩12分',
#    '築32年',
#    '5階建',
#    '3階',
#    '17.8万円',
#    '10000円',
#    '17.8万円',
#    '21.36万円',
#    '2LDK',
#    '59.85m2',
#    'https://suumo.jp/chintai/jnc_000085324912/?bc=100342155569'],),
#  (['賃貸マンション',
#    'ザ・プレミアムキューブG東中野',
#    '東京都中野区東中野５',
#    'ＪＲ中央線/東中野駅 歩7分',
#    '東京メトロ東西線/落合駅 歩7分',
#    'ＪＲ山手線/高田馬場駅 歩21分',
#    '新築',
#    '5階建',
#    '1階',
#    '11.35万円',
#    '15000円',
#    '-',
#    '11.35万円',
#    '2K',
#    '25.5m2',
#    'https://suumo.jp/chintai/jnc_000085010262/?bc=100351426330'],),
#  (['賃貸マンション',
#    'ザ・プレミアムキューブG東中野',
#    '東京都中野区東中野５',
#    'ＪＲ中央線/東中野駅 歩7分',
#    '東京メトロ東西線/落合駅 歩7分',
#    'ＪＲ山手線/高田馬場駅 歩21分',
#    '新築',
#    '5階建',
#    '1階',
#    '11.4万円',
#    '15000円',
#    '-',
#    '11.4万円',
#    '2K',
#    '25.98m2',
#    'https://suumo.jp/chintai/jnc_000086598490/?bc=100354729150'],),
#  (['賃貸マンション',
#    'ザ・プレミアムキューブG東中野',
#    '東京都中野区東中野５',
#    'ＪＲ中央線/東中野駅 歩7分',
#    '東京メトロ東西線/落合駅 歩7分',
#    'ＪＲ山手線/高田馬場駅 歩21分',
#    '新築',
#    '5階建',
#    '1階',
#    '11.4万円',
#    '15000円',
#    '-',
#    '11.4万円',
#    '2K',
#    '25.98m2',
#    'https://suumo.jp/chintai/jnc_000086598488/?bc=100354729147'],),
#  (['賃貸マンション',
#    'ザ・プレミアムキューブG東中野',
#    '東京都中野区東中野５',
#    'ＪＲ中央線/東中野駅 歩7分',
#    '東京メトロ東西線/落合駅 歩7分',
#    'ＪＲ山手線/高田馬場駅 歩21分',
#    '新築',
#    '5階建',
#    '1階',
#    '11.4万円',
#    '15000円',
#    '-',
#    '11.4万円',
#    '2K',
#    '25.98m2',
#    'https://suumo.jp/chintai/jnc_000085010248/?bc=100353316388'],),
#  (['賃貸マンション',
#    'ザ・プレミアムキューブG東中野',
#    '東京都中野区東中野５',
#    'ＪＲ中央線/東中野駅 歩7分',
#    '東京メトロ東西線/落合駅 歩7分',
#    'ＪＲ山手線/高田馬場駅 歩21分',
#    '新築',
#    '5階建',
#    '1階',
#    '11.4万円',
#    '15000円',
#    '-',
#    '11.4万円',
#    '2K',
#    '25.98m2',
#    'https://suumo.jp/chintai/jnc_000086598491/?bc=100354729152'],),
#  (['賃貸マンション',
#    'ザ・プレミアムキューブG東中野',
#    '東京都中野区東中野５',
#    'ＪＲ中央線/東中野駅 歩7分',
#    '東京メトロ東西線/落合駅 歩7分',
#    'ＪＲ山手線/高田馬場駅 歩21分',
#    '新築',
#    '5階建',
#    '1階',
#    '11.4万円',
#    '15000円',
#    '-',
#    '11.4万円',
#    '2K',
#    '25.98m2',
#    'https://suumo.jp/chintai/jnc_000086598489/?bc=100354729157'],),
#  (['賃貸マンション',
#    'ザ・プレミアムキューブG東中野',
#    '東京都中野区東中野５',
#    'ＪＲ中央線/東中野駅 歩7分',
#    '東京メトロ東西線/落合駅 歩7分',
#    'ＪＲ山手線/高田馬場駅 歩21分',
#    '新築',
#    '5階建',
#    '1階',
#    '11.4万円',
#    '15000円',
#    '-',
#    '11.4万円',
#    '2K',
#    '25.98m2',
#    'https://suumo.jp/chintai/jnc_000086598487/?bc=100354729160'],),
#  (['賃貸マンション',
#    'ザ・プレミアムキューブG東中野',
#    '東京都中野区東中野５',
#    'ＪＲ中央線/東中野駅 歩7分',
#    '東京メトロ東西線/落合駅 歩7分',
#    'ＪＲ山手線/高田馬場駅 歩21分',
#    '新築',
#    '5階建',
#    '2階',
#    '11.65万円',
#    '15000円',
#    '-',
#    '11.65万円',
#    '2K',
#    '25.9m2',
#    'https://suumo.jp/chintai/jnc_000086598494/?bc=100354729168'],),
#  (['賃貸マンション',
#    'ザ・プレミアムキューブG東中野',
#    '東京都中野区東中野５',
#    'ＪＲ中央線/東中野駅 歩7分',
#    '東京メトロ東西線/落合駅 歩7分',
#    'ＪＲ山手線/高田馬場駅 歩21分',
#    '新築',
#    '5階建',
#    '2階',
#    '11.65万円',
#    '15000円',
#    '-',
#    '11.65万円',
#    '2K',
#    '25.5m2',
#    'https://suumo.jp/chintai/jnc_000086376701/?bc=100353515532'],),
#  (['賃貸マンション',
#    'ザ・プレミアムキューブG東中野',
#    '東京都中野区東中野５',
#    'ＪＲ中央線/東中野駅 歩7分',
#    '東京メトロ東西線/落合駅 歩7分',
#    'ＪＲ山手線/高田馬場駅 歩21分',
#    '新築',
#    '5階建',
#    '2階',
#    '11.65万円',
#    '15000円',
#    '-',
#    '11.65万円',
#    '2K',
#    '25.5m2',
#    'https://suumo.jp/chintai/jnc_000086376700/?bc=100353515496'],),
#  (['賃貸マンション',
#    'ザ・プレミアムキューブG東中野',
#    '東京都中野区東中野５',
#    'ＪＲ中央線/東中野駅 歩7分',
#    '東京メトロ東西線/落合駅 歩7分',
#    'ＪＲ山手線/高田馬場駅 歩21分',
#    '新築',
#    '5階建',
#    '2階',
#    '11.7万円',
#    '15000円',
#    '-',
#    '11.7万円',
#    '2K',
#    '25.98m2',
#    'https://suumo.jp/chintai/jnc_000085010268/?bc=100351432870'],),
#  (['賃貸マンション',
#    'ザ・プレミアムキューブG東中野',
#    '東京都中野区東中野５',
#    'ＪＲ中央線/東中野駅 歩7分',
#    '東京メトロ東西線/落合駅 歩7分',
#    'ＪＲ山手線/高田馬場駅 歩21分',
#    '新築',
#    '5階建',
#    '2階',
#    '11.7万円',
#    '15000円',
#    '-',
#    '11.7万円',
#    '2K',
#    '25.98m2',
#    'https://suumo.jp/chintai/jnc_000085010269/?bc=100355042788'],),
#  (['賃貸マンション',
#    'ザ・プレミアムキューブG東中野',
#    '東京都中野区東中野５',
#    'ＪＲ中央線/東中野駅 歩7分',
#    '東京メトロ東西線/落合駅 歩7分',
#    'ＪＲ山手線/高田馬場駅 歩21分',
#    '新築',
#    '5階建',
#    '2階',
#    '11.7万円',
#    '15000円',
#    '-',
#    '11.7万円',
#    '2K',
#    '25.98m2',
#    'https://suumo.jp/chintai/jnc_000085010270/?bc=100351433097'],),
#  (['賃貸マンション',
#    'ザ・プレミアムキューブG東中野',
#    '東京都中野区東中野５',
#    'ＪＲ中央線/東中野駅 歩7分',
#    '東京メトロ東西線/落合駅 歩7分',
#    'ＪＲ山手線/高田馬場駅 歩21分',
#    '新築',
#    '5階建',
#    '2階',
#    '11.7万円',
#    '15000円',
#    '-',
#    '11.7万円',
#    '2K',
#    '25.98m2',
#    'https://suumo.jp/chintai/jnc_000085010271/?bc=100353919042'],),
#  (['賃貸マンション',
#    'ザ・プレミアムキューブG東中野',
#    '東京都中野区東中野５',
#    'ＪＲ中央線/東中野駅 歩7分',
#    '東京メトロ東西線/落合駅 歩7分',
#    'ＪＲ山手線/高田馬場駅 歩21分',
#    '新築',
#    '5階建',
#    '2階',
#    '11.7万円',
#    '15000円',
#    '-',
#    '11.7万円',
#    '2K',
#    '25.98m2',
#    'https://suumo.jp/chintai/jnc_000085010267/?bc=100351432974'],),
#  (['賃貸マンション',
#    'ザ・プレミアムキューブG東中野',
#    '東京都中野区東中野５',
#    'ＪＲ中央線/東中野駅 歩7分',
#    '東京メトロ東西線/落合駅 歩7分',
#    'ＪＲ山手線/高田馬場駅 歩21分',
#    '新築',
#    '5階建',
#    '2階',
#    '11.7万円',
#    '15000円',
#    '-',
#    '11.7万円',
#    '2K',
#    '25.9m2',
#    'https://suumo.jp/chintai/jnc_000085010281/?bc=100345787975'],),
#  (['賃貸マンション',
#    'ザ・プレミアムキューブG東中野',
#    '東京都中野区東中野５',
#    'ＪＲ中央線/東中野駅 歩7分',
#    '東京メトロ東西線/落合駅 歩7分',
#    'ＪＲ山手線/高田馬場駅 歩21分',
#    '新築',
#    '5階建',
#    '3階',
#    '11.7万円',
#    '15000円',
#    '-',
#    '11.7万円',
#    '2K',
#    '25.9m2',
#    'https://suumo.jp/chintai/jnc_000085010292/?bc=100345787938'],),
#  (['賃貸マンション',
#    'ザ・プレミアムキューブG東中野',
#    '東京都中野区東中野５',
#    'ＪＲ中央線/東中野駅 歩7分',
#    '東京メトロ東西線/落合駅 歩7分',
#    'ＪＲ山手線/高田馬場駅 歩21分',
#    '新築',
#    '5階建',
#    '3階',
#    '11.7万円',
#    '15000円',
#    '-',
#    '11.7万円',
#    '2K',
#    '25.5m2',
#    'https://suumo.jp/chintai/jnc_000085010290/?bc=100345787995'],),
#  (['賃貸マンション',
#    'ザ・プレミアムキューブG東中野',
#    '東京都中野区東中野５',
#    'ＪＲ中央線/東中野駅 歩7分',
#    '東京メトロ東西線/落合駅 歩7分',
#    'ＪＲ山手線/高田馬場駅 歩21分',
#    '新築',
#    '5階建',
#    '3階',
#    '11.7万円',
#    '15000円',
#    '-',
#    '11.7万円',
#    '2K',
#    '25.5m2',
#    'https://suumo.jp/chintai/jnc_000085010289/?bc=100345788010'],),
#  (['賃貸マンション',
#    'ザ・プレミアムキューブG東中野',
#    '東京都中野区東中野５',
#    'ＪＲ中央線/東中野駅 歩7分',
#    '東京メトロ東西線/落合駅 歩7分',
#    'ＪＲ山手線/高田馬場駅 歩21分',
#    '新築',
#    '5階建',
#    '3階',
#    '11.75万円',
#    '15000円',
#    '-',
#    '11.75万円',
#    '2K',
#    '25.98m2',
#    'https://suumo.jp/chintai/jnc_000086598497/?bc=100355137621'],),
#  (['賃貸マンション',
#    'ザ・プレミアムキューブG東中野',
#    '東京都中野区東中野５',
#    'ＪＲ中央線/東中野駅 歩7分',
#    '東京メトロ東西線/落合駅 歩7分',
#    'ＪＲ山手線/高田馬場駅 歩21分',
#    '新築',
#    '5階建',
#    '3階',
#    '11.75万円',
#    '15000円',
#    '-',
#    '11.75万円',
#    '2K',
#    '25.98m2',
#    'https://suumo.jp/chintai/jnc_000085010285/?bc=100345787958'],),
#  (['賃貸マンション',
#    'ザ・プレミアムキューブG東中野',
#    '東京都中野区東中野５',
#    'ＪＲ中央線/東中野駅 歩7分',
#    '東京メトロ東西線/落合駅 歩7分',
#    'ＪＲ山手線/高田馬場駅 歩21分',
#    '新築',
#    '5階建',
#    '3階',
#    '11.75万円',
#    '15000円',
#    '-',
#    '11.75万円',
#    '2K',
#    '25.98m2',
#    'https://suumo.jp/chintai/jnc_000086598499/?bc=100355137532'],),
#  (['賃貸マンション',
#    'ザ・プレミアムキューブG東中野',
#    '東京都中野区東中野５',
#    'ＪＲ中央線/東中野駅 歩7分',
#    '東京メトロ東西線/落合駅 歩7分',
#    'ＪＲ山手線/高田馬場駅 歩21分',
#    '新築',
#    '5階建',
#    '3階',
#    '11.75万円',
#    '15000円',
#    '-',
#    '11.75万円',
#    '2K',
#    '25.98m2',
#    'https://suumo.jp/chintai/jnc_000086598498/?bc=100355137561'],),
#  (['賃貸マンション',
#    'ザ・プレミアムキューブG東中野',
#    '東京都中野区東中野５',
#    'ＪＲ中央線/東中野駅 歩7分',
#    '東京メトロ東西線/落合駅 歩7分',
#    'ＪＲ山手線/高田馬場駅 歩21分',
#    '新築',
#    '5階建',
#    '3階',
#    '11.75万円',
#    '15000円',
#    '-',
#    '11.75万円',
#    '2K',
#    '25.98m2',
#    'https://suumo.jp/chintai/jnc_000086598500/?bc=100355137547'],),
#  (['賃貸マンション',
#    'ザ・プレミアムキューブG東中野',
#    '東京都中野区東中野５',
#    'ＪＲ中央線/東中野駅 歩7分',
#    '東京メトロ東西線/落合駅 歩7分',
#    'ＪＲ山手線/高田馬場駅 歩21分',
#    '新築',
#    '5階建',
#    '3階',
#    '11.75万円',
#    '15000円',
#    '-',
#    '11.75万円',
#    '2K',
#    '25.98m2',
#    'https://suumo.jp/chintai/jnc_000085010284/?bc=100345787976'],),
#  (['賃貸マンション',
#    'ザ・プレミアムキューブG東中野',
#    '東京都中野区東中野５',
#    'ＪＲ中央線/東中野駅 歩7分',
#    '東京メトロ東西線/落合駅 歩7分',
#    'ＪＲ山手線/高田馬場駅 歩21分',
#    '新築',
#    '5階建',
#    '4階',
#    '11.75万円',
#    '15000円',
#    '-',
#    '11.75万円',
#    '2K',
#    '25.9m2',
#    'https://suumo.jp/chintai/jnc_000085010318/?bc=100345788008'],),
#  (['賃貸マンション',
#    'ザ・プレミアムキューブG東中野',
#    '東京都中野区東中野５',
#    'ＪＲ中央線/東中野駅 歩7分',
#    '東京メトロ東西線/落合駅 歩7分',
#    'ＪＲ山手線/高田馬場駅 歩21分',
#    '新築',
#    '5階建',
#    '4階',
#    '11.75万円',
#    '15000円',
#    '-',
#    '11.75万円',
#    '2K',
#    '25.9m2',
#    'https://suumo.jp/chintai/jnc_000085010317/?bc=100345787994'],),
#  (['賃貸マンション',
#    'ザ・プレミアムキューブG東中野',
#    '東京都中野区東中野５',
#    'ＪＲ中央線/東中野駅 歩7分',
#    '東京メトロ東西線/落合駅 歩7分',
#    'ＪＲ山手線/高田馬場駅 歩21分',
#    '新築',
#    '5階建',
#    '3階',
#    '11.75万円',
#    '15000円',
#    '-',
#    '11.75万円',
#    '2K',
#    '25.9m2',
#    'https://suumo.jp/chintai/jnc_000086598510/?bc=100355137601'],),
#  (['賃貸マンション',
#    'ザ・プレミアムキューブG東中野',
#    '東京都中野区東中野５',
#    'ＪＲ中央線/東中野駅 歩7分',
#    '東京メトロ東西線/落合駅 歩7分',
#    'ＪＲ山手線/高田馬場駅 歩21分',
#    '新築',
#    '5階建',
#    '4階',
#    '11.8万円',
#    '15000円',
#    '-',
#    '11.8万円',
#    '2K',
#    '25.98m2',
#    'https://suumo.jp/chintai/jnc_000085010300/?bc=100345788005'],),
#  (['賃貸マンション',
#    'ザ・プレミアムキューブG東中野',
#    '東京都中野区東中野５',
#    'ＪＲ中央線/東中野駅 歩7分',
#    '東京メトロ東西線/落合駅 歩7分',
#    'ＪＲ山手線/高田馬場駅 歩21分',
#    '新築',
#    '5階建',
#    '4階',
#    '11.8万円',
#    '15000円',
#    '-',
#    '11.8万円',
#    '2K',
#    '25.98m2',
#    'https://suumo.jp/chintai/jnc_000085010299/?bc=100345787999'],),
#  (['賃貸マンション',
#    'ザ・プレミアムキューブG東中野',
#    '東京都中野区東中野５',
#    'ＪＲ中央線/東中野駅 歩7分',
#    '東京メトロ東西線/落合駅 歩7分',
#    'ＪＲ山手線/高田馬場駅 歩21分',
#    '新築',
#    '5階建',
#    '4階',
#    '11.8万円',
#    '15000円',
#    '-',
#    '11.8万円',
#    '2K',
#    '25.98m2',
#    'https://suumo.jp/chintai/jnc_000085010303/?bc=100345787991'],),
#  (['賃貸マンション',
#    'ザ・プレミアムキューブG東中野',
#    '東京都中野区東中野５',
#    'ＪＲ中央線/東中野駅 歩7分',
#    '東京メトロ東西線/落合駅 歩7分',
#    'ＪＲ山手線/高田馬場駅 歩21分',
#    '新築',
#    '5階建',
#    '4階',
#    '11.8万円',
#    '15000円',
#    '-',
#    '11.8万円',
#    '2K',
#    '25.98m2',
#    'https://suumo.jp/chintai/jnc_000085010301/?bc=100355137625'],),
#  (['賃貸マンション',
#    'ザ・プレミアムキューブG東中野',
#    '東京都中野区東中野５',
#    'ＪＲ中央線/東中野駅 歩7分',
#    '東京メトロ東西線/落合駅 歩7分',
#    'ＪＲ山手線/高田馬場駅 歩21分',
#    '新築',
#    '5階建',
#    '4階',
#    '11.8万円',
#    '15000円',
#    '-',
#    '11.8万円',
#    '2K',
#    '25.98m2',
#    'https://suumo.jp/chintai/jnc_000085010302/?bc=100355137641'],),
#  (['賃貸マンション',
#    'ザ・プレミアムキューブG東中野',
#    '東京都中野区東中野５',
#    'ＪＲ中央線/東中野駅 歩7分',
#    '東京メトロ東西線/落合駅 歩7分',
#    'ＪＲ山手線/高田馬場駅 歩21分',
#    '新築',
#    '5階建',
#    '4階',
#    '11.8万円',
#    '15000円',
#    '-',
#    '11.8万円',
#    '2K',
#    '25.9m2',
#    'https://suumo.jp/chintai/jnc_000085010319/?bc=100345787940'],),
#  (['賃貸マンション',
#    'ザ・プレミアムキューブG東中野',
#    '東京都中野区東中野５',
#    'ＪＲ中央線/東中野駅 歩7分',
#    '東京メトロ東西線/落合駅 歩7分',
#    'ＪＲ山手線/高田馬場駅 歩21分',
#    '新築',
#    '5階建',
#    '5階',
#    '11.85万円',
#    '15000円',
#    '-',
#    '11.85万円',
#    '2K',
#    '25.98m2',
#    'https://suumo.jp/chintai/jnc_000086598512/?bc=100355137591'],),
#  (['賃貸マンション',
#    'ザ・プレミアムキューブG東中野',
#    '東京都中野区東中野５',
#    'ＪＲ中央線/東中野駅 歩7分',
#    '東京メトロ東西線/落合駅 歩7分',
#    'ＪＲ山手線/高田馬場駅 歩21分',
#    '新築',
#    '5階建',
#    '5階',
#    '11.85万円',
#    '15000円',
#    '-',
#    '11.85万円',
#    '2K',
#    '25.98m2',
#    'https://suumo.jp/chintai/jnc_000086598511/?bc=100355137546'],),
#  (['賃貸マンション',
#    'ザ・プレミアムキューブG東中野',
#    '東京都中野区東中野５',
#    'ＪＲ中央線/東中野駅 歩7分',
#    '東京メトロ東西線/落合駅 歩7分',
#    'ＪＲ山手線/高田馬場駅 歩21分',
#    '新築',
#    '5階建',
#    '5階',
#    '11.85万円',
#    '15000円',
#    '-',
#    '11.85万円',
#    '2K',
#    '25.98m2',
#    'https://suumo.jp/chintai/jnc_000084778350/?bc=100354541351'],),
#  (['賃貸マンション',
#    'ザ・プレミアムキューブG東中野',
#    '東京都中野区東中野５',
#    'ＪＲ中央線/東中野駅 歩7分',
#    '東京メトロ東西線/落合駅 歩7分',
#    'ＪＲ山手線/高田馬場駅 歩21分',
#    '新築',
#    '5階建',
#    '5階',
#    '11.85万円',
#    '15000円',
#    '-',
#    '11.85万円',
#    '2K',
#    '25.98m2',
#    'https://suumo.jp/chintai/jnc_000086598513/?bc=100354541475'],),
#  (['賃貸マンション',
#    'フジハイツ',
#    '東京都品川区中延６',
#    '東急大井町線/荏原町駅 歩7分',
#    '都営浅草線/馬込駅 歩8分',
#    '東急大井町線/中延駅 歩10分',
#    '築40年',
#    '3階建',
#    '3階',
#    '10万円',
#    '-',
#    '10万円',
#    '-',
#    '3K',
#    '49m2',
#    'https://suumo.jp/chintai/jnc_000083785065/?bc=100336451160'],),
#  (['賃貸マンション',
#    'ハーモニーレジデンス中野本町パークサイド',
#    '東京都中野区本町５',
#    '東京メトロ丸ノ内線/中野新橋駅 歩6分',
#    '東京メトロ丸ノ内線/新中野駅 歩9分',
#    'ＪＲ中央線/中野駅 歩20分',
#    '築3年',
#    '4階建',
#    '1階',
#    '10.95万円',
#    '15000円',
#    '-',
#    '-',
#    '2K',
#    '25.5m2',
#    'https://suumo.jp/chintai/jnc_000075954238/?bc=100351960281'],),
#  (['賃貸マンション',
#    'ハーモニーレジデンス中野本町パークサイド',
#    '東京都中野区本町５',
#    '東京メトロ丸ノ内線/中野新橋駅 歩6分',
#    '東京メトロ丸ノ内線/新中野駅 歩9分',
#    'ＪＲ中央線/中野駅 歩20分',
#    '築3年',
#    '4階建',
#    '1階',
#    '11.1万円',
#    '15000円',
#    '-',
#    '-',
#    '2K',
#    '25.5m2',
#    'https://suumo.jp/chintai/jnc_000086357748/?bc=100353272282'],),
#  (['賃貸マンション',
#    'ハーモニーレジデンス中野本町パークサイド',
#    '東京都中野区本町５',
#    '東京メトロ丸ノ内線/中野新橋駅 歩6分',
#    '東京メトロ丸ノ内線/新中野駅 歩9分',
#    'ＪＲ中央線/中野駅 歩20分',
#    '築3年',
#    '4階建',
#    '4階',
#    '11.5万円',
#    '15000円',
#    '-',
#    '-',
#    '2K',
#    '25.5m2',
#    'https://suumo.jp/chintai/jnc_000086625871/?bc=100354912371'],),
#  (['賃貸マンション',
#    'HF西新宿レジデンスWEST',
#    '東京都新宿区西新宿８',
#    '東京メトロ丸ノ内線/西新宿駅 歩6分',
#    'ＪＲ中央線/大久保駅 歩7分',
#    '西武新宿線/西武新宿駅 歩11分',
#    '築18年',
#    '12階建',
#    '11階',
#    '13.6万円',
#    '12000円',
#    '13.6万円',
#    '-',
#    '11DK',
#    '32.64m2',
#    'https://suumo.jp/chintai/jnc_000086383687/?bc=100352984478'],),
#  (['賃貸マンション',
#    'プラネット',
#    '東京都江戸川区東小岩５',
#    'ＪＲ総武線/小岩駅 歩10分',
#    '京成本線/江戸川駅 歩14分',
#    '京成本線/京成小岩駅 歩18分',
#    '築3年',
#    '2階建',
#    '1階',
#    '6.5万円',
#    '2000円',
#    '6.5万円',
#    '6.5万円',
#    '10K',
#    '25.14m2',
#    'https://suumo.jp/chintai/jnc_000069082397/?bc=100354497924'],),
#  (['賃貸マンション',
#    '日神デュオステージ押上',
#    '東京都墨田区京島２',
#    '東京メトロ半蔵門線/押上駅 歩10分',
#    '京成押上線/京成曳舟駅 歩7分',
#    '東武伊勢崎線/曳舟駅 歩8分',
#    '築15年',
#    '6階建',
#    '1階',
#    '8.5万円',
#    '11000円',
#    '-',
#    '8.5万円',
#    '2K',
#    '30.22m2',
#    'https://suumo.jp/chintai/jnc_000086659395/?bc=100355055164'],),
#  (['賃貸マンション',
#    'ライトテラス上野',
#    '東京都台東区下谷１',
#    'ＪＲ山手線/上野駅 歩9分',
#    '東京メトロ日比谷線/入谷駅 歩3分',
#    'ＪＲ京浜東北線/鶯谷駅 歩7分',
#    '築4年',
#    '13階建',
#    '10階',
#    '12.5万円',
#    '10000円',
#    '-',
#    '-',
#    '2K',
#    '28.03m2',
#    'https://suumo.jp/chintai/jnc_000086625488/?bc=100354744481'],),
#  (['賃貸マンション',
#    'ライトテラス上野',
#    '東京都台東区下谷１',
#    'ＪＲ山手線/上野駅 歩9分',
#    '東京メトロ日比谷線/入谷駅 歩3分',
#    'ＪＲ京浜東北線/鶯谷駅 歩7分',
#    '築4年',
#    '13階建',
#    '7階',
#    '12.2万円',
#    '15000円',
#    '-',
#    '-',
#    '2K',
#    '28.03m2',
#    'https://suumo.jp/chintai/jnc_000086066902/?bc=100350966930'],),
#  (['賃貸マンション',
#    'ライトテラス上野',
#    '東京都台東区下谷１',
#    'ＪＲ山手線/上野駅 歩9分',
#    '東京メトロ日比谷線/入谷駅 歩3分',
#    'ＪＲ京浜東北線/鶯谷駅 歩7分',
#    '築4年',
#    '13階建',
#    '10階',
#    '12.5万円',
#    '15000円',
#    '-',
#    '-',
#    '2K',
#    '28.03m2',
#    'https://suumo.jp/chintai/jnc_000086059601/?bc=100342827976'],),
#  (['賃貸マンション',
#    'ライトテラス上野',
#    '東京都台東区下谷１',
#    'ＪＲ山手線/上野駅 歩9分',
#    '東京メトロ日比谷線/入谷駅 歩3分',
#    'ＪＲ京浜東北線/鶯谷駅 歩7分',
#    '築4年',
#    '13階建',
#    '10階',
#    '12.6万円',
#    '15000円',
#    '12.6万円',
#    '12.6万円',
#    '2K',
#    '28.03m2',
#    'https://suumo.jp/chintai/jnc_000084811629/?bc=100343941853'],),
#  (['賃貸マンション',
#    'アヴァンティーク銀座一丁目',
#    '東京都中央区銀座１',
#    '東京メトロ銀座線/銀座駅 歩8分',
#    '都営浅草線/宝町駅 歩4分',
#    '東京メトロ有楽町線/銀座一丁目駅 歩4分',
#    '築23年',
#    '13階建',
#    '4階',
#    '15.6万円',
#    '14000円',
#    '15.6万円',
#    '15.6万円',
#    '2K',
#    '40.81m2',
#    'https://suumo.jp/chintai/jnc_000068734314/?bc=100347639296'],),
#  (['賃貸マンション',
#    '東京メトロ日比谷線 入谷駅 13階建 築4年',
#    '東京都台東区下谷１',
#    '東京メトロ日比谷線/入谷駅 歩3分',
#    'ＪＲ山手線/上野駅 歩9分',
#    'ＪＲ京浜東北線/鶯谷駅 歩8分',
#    '築4年',
#    '13階建',
#    '7階',
#    '12.2万円',
#    '15000円',
#    '-',
#    '-',
#    '2K',
#    '28.03m2',
#    'https://suumo.jp/chintai/jnc_000086082902/?bc=100352834755'],),
#  (['賃貸マンション',
#    '東京メトロ日比谷線 入谷駅 13階建 築4年',
#    '東京都台東区下谷１',
#    '東京メトロ日比谷線/入谷駅 歩3分',
#    'ＪＲ山手線/上野駅 歩9分',
#    'ＪＲ京浜東北線/鶯谷駅 歩8分',
#    '築4年',
#    '13階建',
#    '10階',
#    '12.5万円',
#    '15000円',
#    '-',
#    '-',
#    '2K',
#    '28.03m2',
#    'https://suumo.jp/chintai/jnc_000086072679/?bc=100334371085'],),
#  ...]

# %%
#Step2データを整形する

#リスト内包表記を使用し、data_samplesリストの各要素からアイテムを取得し、新しいリスト split_data_samplesへ格納する
#item[0]となっているのは、タプル内の要素が1つのリストのみであるため＝([],)となっている
split_data_samples = [item[0] for item in data_samples]

# DataFrame の作成
df = pd.DataFrame(split_data_samples)

df.columns = ['カテゴリ', '物件名', '所在地', 'アクセス1', 'アクセス2', 'アクセス3', '築年数', '建物の階数', '部屋の階数', '賃料', '管理費', '敷金', '礼金', '間取り', '面積', 'URL']
df
# Out:
#          カテゴリ                  物件名          所在地                 アクセス1  \
# 0      賃貸一戸建て                  奥山方  東京都荒川区西日暮里２        ＪＲ山手線/日暮里駅 歩5分
# 1     賃貸マンション  ＪＲ中央線 東中野駅 3階建 築33年   東京都新宿区北新宿３        ＪＲ中央線/東中野駅 歩7分
# 2     賃貸マンション        kinomori代々木上原    東京都渋谷区上原２  東京メトロ千代田線/代々木公園駅 歩9分
# 3     賃貸マンション        kinomori代々木上原    東京都渋谷区上原２  東京メトロ千代田線/代々木公園駅 歩9分
# 4     賃貸マンション        kinomori代々木上原    東京都渋谷区上原２  東京メトロ千代田線/代々木公園駅 歩9分
# ...       ...                  ...          ...                   ...
# 1775  賃貸マンション           ジェノヴィア池袋本町  東京都豊島区池袋本町２        東武東上線/下板橋駅 歩8分
# 1776  賃貸マンション    京王線 明大前駅 9階建 築46年    東京都杉並区和泉２          京王線/明大前駅 歩5分
# 1777  賃貸マンション    京王線 明大前駅 9階建 築46年    東京都杉並区和泉２          京王線/明大前駅 歩5分
# 1778  賃貸マンション              ベル　パエーゼ   東京都中野区東中野１        ＪＲ総武線/東中野駅 歩7分
# 1779   賃貸一戸建て            赤塚新町２丁目貸家  東京都板橋区赤塚新町２  東京メトロ有楽町線/地下鉄赤塚駅 歩4分
#
#                      アクセス2                 アクセス3   築年数 建物の階数 部屋の階数      賃料  \
# 0         ＪＲ山手線/西日暮里駅 歩10分        ＪＲ常磐線/三河島駅 歩9分  築41年   2階建    1階    15万円
# 1     東京メトロ丸ノ内線/中野坂上駅 歩13分     東京メトロ東西線/落合駅 歩15分  築33年   3階建    1階    19万円
# 2          小田急線/代々木八幡駅 歩8分       小田急線/代々木上原駅 歩7分   築1年   4階建    4階  12.7万円
# 3          小田急線/代々木八幡駅 歩8分       小田急線/代々木上原駅 歩7分   築1年   4階建    1階    13万円
# 4          小田急線/代々木八幡駅 歩8分       小田急線/代々木上原駅 歩7分   築1年   4階建    2階  13.1万円
# ...                    ...                   ...   ...   ...   ...     ...
# 1775        東武東上線/北池袋駅 歩9分        ＪＲ埼京線/板橋駅 歩15分    新築   7階建    6階  11.9万円
# 1776       京王井の頭線/明大前駅 歩5分         京王線/代田橋駅 歩10分  築46年   9階建    6階  11.9万円
# 1777       京王井の頭線/明大前駅 歩5分         京王線/代田橋駅 歩10分  築46年   9階建    2階  13.5万円
# 1778   東京メトロ丸ノ内線/中野坂上駅 歩9分       ＪＲ総武線/大久保駅 歩12分  築21年   3階建    1階    11万円
# 1779        東武東上線/下赤塚駅 歩7分  東京メトロ副都心線/地下鉄赤塚駅 歩4分  築32年   3階建     -  17.5万円
#
#          管理費       敷金      礼金    間取り        面積  \
# 0          -     15万円    15万円     4K   73.75m2
# 1     10000円        -    19万円    4SK      80m2
# 2     10000円        -       -     2K    23.7m2
# 3     10000円        -       -     2K   24.08m2
# 4     10000円        -       -     2K   24.08m2
# ...      ...      ...     ...    ...       ...
# 1775  10000円        -       -     2K   25.95m2
# 1776       -  17.85万円       -   2LDK    43.6m2
# 1777       -  20.25万円       -    3DK   51.46m2
# 1778   5000円     11万円    11万円     2K    36.7m2
# 1779  15000円     35万円  17.5万円  3SLDK  135.73m2
#
#                                                     URL
# 0     https://suumo.jp/chintai/jnc_000086740977/?bc=...
# 1     https://suumo.jp/chintai/jnc_000086029265/?bc=...
# 2     https://suumo.jp/chintai/jnc_000086724239/?bc=...
# 3     https://suumo.jp/chintai/jnc_000086724226/?bc=...
# 4     https://suumo.jp/chintai/jnc_000086724228/?bc=...
# ...                                                 ...
# 1775  https://suumo.jp/chintai/jnc_000084625799/?bc=...
# 1776  https://suumo.jp/chintai/jnc_000017540325/?bc=...
# 1777  https://suumo.jp/chintai/jnc_000086104453/?bc=...
# 1778  https://suumo.jp/chintai/jnc_000086763242/?bc=...
# 1779  https://suumo.jp/chintai/jnc_000086741031/?bc=...
#
# [1780 rows x 16 columns]

# %%
#Step3
#出力した結果をCSVファイルに保存する
suumo_df = df
suumo_df.to_csv('suumo_data.csv', index=False, encoding='utf-8-sig')
